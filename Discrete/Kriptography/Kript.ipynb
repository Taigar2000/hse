# %%
import numpy as np
import matplotlib.pyplot as plt
import copy
from sympy import *

fl=open("result.txt","w")


def sum(a):
    b=0
    for i in a:
        b+=i
    return b

def cut(f, counter=-1):
    if(len(f)==0): return []
    i=0
    while(f[i]==0):
        i+=1
        if(i==counter): break
        if(i==len(f)): return []
    return f[i::]

def analit(a,st=0):
    b=len(a)-1+st
    s=""
    for i in a:
        if(i!=0):
            if(i!=1 or b==0 or 1):
                s+=str(i)
            if(b>0):s+="*x**"+str(b)
            s+="+"
        b-=1
    if(len(s)==0):s="0+"
    return str(simplify(s[0:-1:]))


def GCD(f,g,mod,show=1,write=1):
    #if(len(f)<len(g)):f,g=g,f
    if(show):print("Counting for mod "+str(mod))
    if(write):fl.write("\n\nCounting for mod "+str(mod)+"\n")
    retarr=[]
    retarr.append([copy.deepcopy(f),[-0],1,0])
    if(show):print(str(retarr[-1]))
    if(write):fl.write(str(retarr[-1])+"\n")
    retarr.append([copy.deepcopy(g),[-0],0,1])
    if(show):print(str(retarr[-1]))
    if(write):fl.write(str(retarr[-1])+"\n")


    g=cut(g)
    while(len(g)>0):
        n = len(g)#min(len(f),len(g))
        s=""
        ka=[]
        uv=[]
        breakf=0
        while(len(f)>=len(g)):
            k=0
            iter=0
            
            if(show):
                print("\n\t"+analit(f))
            if(write):
                fl.write("\n\t"+analit(f))
                
            while(f[0]>0):
                k+=1
                f[0]=(f[0]-g[0]+mod)%mod
                iter+=1
                if(iter==mod):
                    breakf=1
                    k=1
                    break
                    #retarr.append([copy.deepcopy(f),"nan","nan","nan"])
                    #return retarr
            
            psa=[(g[i]*k)%mod for i in range (n)]
            for i in range(1,n):
                f[i]=(f[i]-g[i]*k+mod)%mod
#                 while(k<0):
#                     k=(k+mod)%mod
            s+=str(k)
            ka.append(k)
            d=len(f)-n

            f=cut(f,1)        
            
            if(show):
                print("\n\t-"+analit(psa,d))
                print("\n\t="+analit(f))
            if(write):
                fl.write("\n\t-"+analit(psa,d))
                fl.write("\n\t="+analit(f)+"\n")
                
            
            if(d>0):s+="x**"+str(d)
            s+="+"
            if(breakf):break
        s=s[0:-1:]
        if(len(ka)==0):ka=[0]
        f=cut(f)
        #retarr.append([copy.deepcopy(f),s,"("+str(retarr[-2][2])+")-("+s+")*("+str(retarr[-1][2])+")","("+str(retarr[-2][3])+")-("+s+")*("+str(retarr[-1][3])+")"])
        retarr.append([copy.deepcopy(f),ka,simplify("("+str(retarr[-2][2])+")-("+analit(ka)+")*("+str(retarr[-1][2])+")"),simplify("("+str(retarr[-2][3])+")-("+analit(ka)+")*("+str(retarr[-1][3])+")")])
        if(show):print(str(retarr[-1]))
        if(write):fl.write(str(retarr[-1])+"\n")
    #     print(str(f))
    #     fl.write(str(f))
    #     print(g)
    #     fl.write(str(g))
    #     print(k)
    #     fl.write(str(k))
    #     print((g*k)%mod)
    #     fl.write(str((g*k)%mod))

        if(write): fl.flush()

        if(breakf and len(f)>=len(g)):break
        
        f,g=g,f
        
        
    if(show):print("End of counting")
    if(write):fl.write("End of counting"+"\n")
    return retarr

def rev(f,g,mod,show,write):
    #g=[mod for i in f]
    f=[f]
    g=[g]
    d=GCD(g,f,mod,show,write)
    flagf=1
    for i in ((d[::-1])[::]):
        try: 
#         if(flagf):
#             flagf=0
#             continue
         if(len(i[0])==1):           
            b=copy.deepcopy(i)
            #print (b)
            sc=1
            for j in range (1,mod+1):
                sc=j
                if(b[0][-1]==1): 
                    return int(b[-1])*sc
                    break
                b[0][-1]=(b[0][-1]+i[0][-1])%mod
                #print(b)
        except:
            pass
    return "nan"



if (0 and __name__=="__main__"):

    #f=np.array([4,4,4,2,2,0,3,4,1])
    #g=np.array([3,4,0,2,1,2])
    p=np.array([4,2,1,2,2,4,4,1,4]) #P(x)
    f=np.array([3,2,4,0,3,1]) #F(x)
    mod=5#np.array([3,3,3,3,3])

    x=symbols("x")
    
    res=GCD(copy.deepcopy(p),copy.deepcopy(f),mod)
    print("GCD(P,F): "+str(simplify("("+str(simplify("("+str(res[-2][-2])+")*("+str(analit(res[0][0]))+") + ("+str(res[-2][-1])+")*("+str(analit(res[1][0]))+")"))+")%"+str(mod))))
    fl.write("GCD(P,F): "+str(simplify("("+str(simplify("("+str(res[-2][-2])+")*("+str(analit(res[0][0]))+") + ("+str(res[-2][-1])+")*("+str(analit(res[1][0]))+")"))+")%"+str(mod))))
    #Obratnii k f
    print("Obratnii k P = "+str(rev(copy.deepcopy(p),mod,1,1)))
    fl.write("Obratnii k P = "+str(rev(copy.deepcopy(p),mod,0,0)))
    #Obratnii k g
    print("Obratnii k F = "+str(rev(copy.deepcopy(f),mod,1,1)))
    fl.write("Obratnii k F = "+str(rev(copy.deepcopy(f),mod,0,0)))

    #print("Obratnii k g = "+str(rev([3,2],9,1,0)))

fl.close()

# %%
import numpy as np
import matplotlib.pyplot as plt
import copy
#from sympy import *

# %%
def printf(fl,s):
    print(s,end="")
    try: fl.write(s)
    except: pass

# %%
def add(p,q=[],a=0, show=0,write=0,fl=0,mod=1):
    s=""
    s2=""
    #print(1)
    if(q!=[] and (not(p[0]==q[0] and p[1]==q[1]))):
        #print(1.1)
        l=(int(q[1]-p[1]))*rev(int(q[0]-p[0]),mod,mod,0,0)
        #print(1.2)
        s="((("+str(q[1])+")-("+str(p[1])+"))/(("+str(q[0])+")-("+str(p[0])+")))"
        s2="((("+str(q[1])+")-("+str(p[1])+"))*("+str(rev(int(q[0]-p[0]),mod,mod,0,0))+"))"
#        if(show): print("("+str(q[1])+"-"+str(p[1])+")/("+str(q[0])+"-"+str(p[0])+")")
#        if(write): fl.write("("+str(q[1])+"-"+str(p[1])+")/("+str(q[0])+"-"+str(p[0])+")\n")
    #print(2)
    if(q==[] or (p[0]==q[0] and p[1]==q[1])):
        l=(int(3*(p[0]**2)+a))*rev(int(2*p[1]),mod,mod,0,0)
        s="((3*("+str(p[0])+")**2+("+str(a)+"))/(2*("+str(p[1])+")))"
        s2="((3*("+str(p[0])+")**2+("+str(a)+"))*("+str(rev(int(2*p[1]),mod,mod,0,0))+"))"
#        if(show): print("(3*"+str(p[0])+"**2+"+str(a)+")/(2*"+str(p[1])+")")
#        if(write): fl.write("(3*"+str(p[0])+"**2+"+str(a)+")/(2*"+str(p[1])+")")
    #print(3)
    xs=((int(l**2)-p[0]-q[0])%mod+mod)%mod
    so=s+"**2-("+str(p[0])+")-("+str(q[0])+")" + " =\n " + s2+"**2-("+str(p[0])+")-("+str(q[0])+")" + " =\n "+str(xs)
    if(show): print(so)
    if(write): fl.write(so)
    ys=((-p[1]+int(l*(p[0]-xs)))%mod+mod)%mod
    so="-("+str(p[1])+")+"+s+"*(("+str(p[0])+")-("+str(xs)+"))" + " =\n " + "-("+str(p[1])+")+"+s2+"*(("+str(p[0])+")-("+str(xs)+"))" + " =\n "+str(ys)
    if(show): print(so)
    if(write): fl.write(so)
    return [xs,ys]

def mult(p,a,n,show=0,write=0,fl=0,mod=1):
    ret=copy.deepcopy(p)
    flag=1
    for i in range(n):
        if(flag): flag=(flag^1)
        ret=add(ret,p,a,(show and i==n-1),(write and i==n-1),fl,mod)
    if(0 and flag):
        if(show): print("("+str(ret[0])+";",end="")
        if(write): fl.write("("+str(ret[0])+";")
        if(show): print(str(ret[1])+")")
        if(write): fl.write(str(ret[1])+")\n")
    return ret

def por(p,a,say=1,sayf=1,show=0,write=0,fl=0,mod=1,retno=1):
    ret=copy.deepcopy(p)
    flag=1
    i=1
    while(i<mod):
        #if(flag): flag=(show^1)
        if(say): print({i:ret[-1]})
        if(sayf): 
            fl.write(str({i:ret[-1]})+"\n")
            fl.flush()
        ret.append(add(ret[-1],p[0],a,show,write,fl,mod))
        if(retno and ret[-1][0]==p[0][0] and ret[-1][1]==p[0][1]): return {i:ret[-1]}
        i+=1

# %%
def solver(fl,p,a,b,q,n,k):
    printf(fl,"Проверка кривой на сингулярность:\n")
    printf(fl,"4*("+str(a)+")**3 - 27*("+str(b)+")**2 = "+str(((4*(a**3)-27*(b**2))%q+q)%q))
    if((((4*(a**3)-27*(b**2))%q+q)%q)!=0):
        printf(fl,"Кривая не сингулярна и подходит для шифрования")
    else:
        printf(fl,"Кривая сингулярна и не подходит для шифрования")
    flag=1
    for i in range(n):
        if(i>k): flag=0
        print("\nPoint "+str(i+1)+" :")
        fl.write("\nPoint "+str(i+1)+" :\n")
        p.append(mult(p[0],a,i,flag,flag,fl,q))
        if(1 or not flag):
            ret=p[-1]
            print("("+str(ret[0])+";",end="")
            fl.write("("+str(ret[0])+";")
            print(str(ret[1])+")")
            fl.write(str(ret[1])+")\n")

    #printf("Порядок элемента: "+str(por(p[0],a,i,flag,flag,fl,q)))

# %%
fl=open("GER/task2n1_GER.txt","w")
p=[[7406,17549]]
a=-2
b=-1
q=18181
n=15
k=5
#add(p[0],p[0],a,0,0,0,q)
solver(fl,p,a,b,q,n,k)

fl.close()
print(((((3*(7406)**2+(-2))/(2*(17549)))**2-(7406)-(7406))+q)%q)
# Out:
# Проверка кривой на сингулярность:
# 4*(-2)**3 - 27*(-1)**2 = 18122Кривая не сингулярна и подходит для шифрования
# Point 1 :
# (7406;17549)
#
# Point 2 :
# ((3*(7406)**2+(-2))/(2*(17549)))**2-(7406)-(7406) =
#  ((3*(7406)**2+(-2))*(8472))**2-(7406)-(7406) =
#  8412
# -(17549)+((3*(7406)**2+(-2))/(2*(17549)))*((7406)-(8412)) =
#  -(17549)+((3*(7406)**2+(-2))*(8472))*((7406)-(8412)) =
#  17258
# (8412;17258)
#
# Point 3 :
# (((17549)-(17258))/((7406)-(8412)))**2-(8412)-(7406) =
#  (((17549)-(17258))*(7970))**2-(8412)-(7406) =
#  1756
# -(17258)+(((17549)-(17258))/((7406)-(8412)))*((8412)-(1756)) =
#  -(17258)+(((17549)-(17258))*(7970))*((8412)-(1756)) =
#  11287
# (1756;11287)
#
# Point 4 :
# (((17549)-(11287))/((7406)-(1756)))**2-(1756)-(7406) =
#  (((17549)-(11287))*(576))**2-(1756)-(7406) =
#  16383
# -(11287)+(((17549)-(11287))/((7406)-(1756)))*((1756)-(16383)) =
#  -(11287)+(((17549)-(11287))*(576))*((1756)-(16383)) =
#  3567
# (16383;3567)
#
# Point 5 :
# (((17549)-(3567))/((7406)-(16383)))**2-(16383)-(7406) =
#  (((17549)-(3567))*(8650))**2-(16383)-(7406) =
#  345
# -(3567)+(((17549)-(3567))/((7406)-(16383)))*((16383)-(345)) =
#  -(3567)+(((17549)-(3567))*(8650))*((16383)-(345)) =
#  6835
# (345;6835)
#
# Point 6 :
# (((17549)-(6835))/((7406)-(345)))**2-(345)-(7406) =
#  (((17549)-(6835))*(12264))**2-(345)-(7406) =
#  13972
# -(6835)+(((17549)-(6835))/((7406)-(345)))*((345)-(13972)) =
#  -(6835)+(((17549)-(6835))*(12264))*((345)-(13972)) =
#  608
# (13972;608)
#
# Point 7 :
# (11996;7845)
#
# Point 8 :
# (10736;13376)
#
# Point 9 :
# (8000;16216)
#
# Point 10 :
# (9740;544)
#
# Point 11 :
# (10988;12942)
#
# Point 12 :
# (7012;15941)
#
# Point 13 :
# (5476;295)
#
# Point 14 :
# (531;8116)
#
# Point 15 :
# (5127;3833)
# 1775.9101085811853

# %%
fl=open("DNA/task2n1_DNA.txt","w")
p=[[10578,9165]]
a=-2
b=-3
q=15313
n=12
k=3

solver(fl,p,a,b,q,n,k)

fl.close()
# Out:
# Проверка кривой на сингулярность:
# 4*(-2)**3 - 27*(-3)**2 = 15038Кривая не сингулярна и подходит для шифрования
# Point 1 :
# (10578;9165)
#
# Point 2 :
# ((3*(10578)**2+(-2))/(2*(9165)))**2-(10578)-(10578) =
#  ((3*(10578)**2+(-2))*(12425))**2-(10578)-(10578) =
#  867
# -(9165)+((3*(10578)**2+(-2))/(2*(9165)))*((10578)-(867)) =
#  -(9165)+((3*(10578)**2+(-2))*(12425))*((10578)-(867)) =
#  10911
# (867;10911)
#
# Point 3 :
# (((9165)-(10911))/((10578)-(867)))**2-(867)-(10578) =
#  (((9165)-(10911))*(2359))**2-(867)-(10578) =
#  12740
# -(10911)+(((9165)-(10911))/((10578)-(867)))*((867)-(12740)) =
#  -(10911)+(((9165)-(10911))*(2359))*((867)-(12740)) =
#  5004
# (12740;5004)
#
# Point 4 :
# (((9165)-(5004))/((10578)-(12740)))**2-(12740)-(10578) =
#  (((9165)-(5004))*(9838))**2-(12740)-(10578) =
#  9199
# -(5004)+(((9165)-(5004))/((10578)-(12740)))*((12740)-(9199)) =
#  -(5004)+(((9165)-(5004))*(9838))*((12740)-(9199)) =
#  12907
# (9199;12907)
#
# Point 5 :
# (464;923)
#
# Point 6 :
# (948;10374)
#
# Point 7 :
# (13904;9590)
#
# Point 8 :
# (2241;1601)
#
# Point 9 :
# (7786;12463)
#
# Point 10 :
# (12283;13504)
#
# Point 11 :
# (14858;8638)
#
# Point 12 :
# (9049;9076)

# %%
p=[[10578,9165]]
a=-2
b=-3
q=15313
n=12
k=3

print(mult(p[0],a,1147,0,0,0,q))
print(add(p[0],p[0],a,0,0,0,q))
# Out:
# [9624, 5172]
# [867, 10911]

# %%
fl=open("task2n1_t.txt","w")
p=[[9062,21551]]
a=-9
b=6
q=25939
n=15
k=3
solver(fl,p,a,b,q,n,k)

fl.close()
print(((((3*(7406)**2+(-2))/(2*(17549)))**2-(7406)-(7406))+q)%q)
# Out:
# Проверка кривой на сингулярность:
# 4*(-9)**3 - 27*(6)**2 = 22051Кривая не сингулярна и подходит для шифрования
# Point 1 :
# (9062;21551)
#
# Point 2 :
# ((3*(9062)**2+(-9))/(2*(21551)))**2-(9062)-(9062) =
#  ((3*(9062)**2+(-9))*(19871))**2-(9062)-(9062) =
#  16565
# -(21551)+((3*(9062)**2+(-9))/(2*(21551)))*((9062)-(16565)) =
#  -(21551)+((3*(9062)**2+(-9))*(19871))*((9062)-(16565)) =
#  10202
# (16565;10202)
#
# Point 3 :
# (((21551)-(10202))/((9062)-(16565)))**2-(16565)-(9062) =
#  (((21551)-(10202))*(13030))**2-(16565)-(9062) =
#  21015
# -(10202)+(((21551)-(10202))/((9062)-(16565)))*((16565)-(21015)) =
#  -(10202)+(((21551)-(10202))*(13030))*((16565)-(21015)) =
#  13839
# (21015;13839)
#
# Point 4 :
# (((21551)-(13839))/((9062)-(21015)))**2-(21015)-(9062) =
#  (((21551)-(13839))*(20963))**2-(21015)-(9062) =
#  10359
# -(13839)+(((21551)-(13839))/((9062)-(21015)))*((21015)-(10359)) =
#  -(13839)+(((21551)-(13839))*(20963))*((21015)-(10359)) =
#  19211
# (10359;19211)
#
# Point 5 :
# (9236;2742)
#
# Point 6 :
# (23011;12104)
#
# Point 7 :
# (15939;15500)
#
# Point 8 :
# (24913;16155)
#
# Point 9 :
# (19533;24613)
#
# Point 10 :
# (22773;15772)
#
# Point 11 :
# (21235;2693)
#
# Point 12 :
# (14516;4514)
#
# Point 13 :
# (11856;8493)
#
# Point 14 :
# (1667;23673)
#
# Point 15 :
# (15836;23179)
# 20029.910108581185

# %%
q=25939
print(((3*(((9062)**2)%q)+(-9))%q))
print(((9062)**2)%q)
print(((2*(21551))%q))
print(((3*(((9062)**2)%q)+(-9))%q)/((2*(21551))%q))
print(rev(17163,q,q,0,0))
print(rev(17163,q,q,0,0)*16840%q)
# Out:
# 16840
# 22909
# 17163
# 0.9811804463089203
# 19871
# 14540

# %%
p=[[10578,9165]]
a=-2
b=-3
q=15313
n=12
k=3

#print(mult(p[0],a,1147,0,0,0,q))

# %%
fl=open("DNA/nodelist.txt","w")
print(por(p,a,1,1,0,0,fl,q))
fl.close()
# Out:
# {1: [10578, 9165]}
# {2: [867, 10911]}
# {3: [12740, 5004]}
# {4: [9199, 12907]}
# {5: [464, 923]}
# {6: [948, 10374]}
# {7: [13904, 9590]}
# {8: [2241, 1601]}
# {9: [7786, 12463]}
# {10: [12283, 13504]}
# {11: [14858, 8638]}
# {12: [9049, 9076]}
# {13: [11049, 11058]}
# {14: [1167, 4080]}
# {15: [1664, 10901]}
# {16: [7928, 1485]}
# {17: [13737, 12537]}
# {18: [1618, 1039]}
# {19: [4734, 14579]}
# {20: [1573, 9686]}
# {21: [14693, 9515]}
# {22: [4349, 11962]}
# {23: [12967, 14699]}
# {24: [2710, 13490]}
# {25: [8331, 9613]}
# {26: [11502, 6046]}
# {27: [7198, 8527]}
# {28: [6205, 9882]}
# {29: [13709, 2862]}
# {30: [3037, 12560]}
# {31: [6218, 2985]}
# {32: [13726, 6041]}
# {33: [6932, 837]}
# {34: [6972, 1684]}
# {35: [2008, 4699]}
# {36: [3129, 6835]}
# {37: [2230, 4656]}
# {38: [513, 4414]}
# {39: [11847, 10346]}
# {40: [15085, 6720]}
# {41: [11524, 6087]}
# {42: [10224, 12766]}
# {43: [1012, 12224]}
# {44: [11264, 2295]}
# {45: [3310, 12695]}
# {46: [10833, 4304]}
# {47: [5518, 968]}
# {48: [14230, 1164]}
# {49: [10465, 9779]}
# {50: [1369, 10044]}
# {51: [13975, 8456]}
# {52: [13585, 9895]}
# {53: [3439, 6608]}
# {54: [7200, 11783]}
# {55: [7104, 13628]}
# {56: [14178, 11963]}
# {57: [6798, 4492]}
# {58: [13552, 2042]}
# {59: [11989, 3220]}
# {60: [10647, 14958]}
# {61: [7534, 3388]}
# {62: [1767, 13518]}
# {63: [12512, 14090]}
# {64: [3381, 11514]}
# {65: [13151, 10907]}
# {66: [4840, 7926]}
# {67: [11495, 8584]}
# {68: [6162, 1246]}
# {69: [13190, 396]}
# {70: [5767, 9384]}
# {71: [11840, 5171]}
# {72: [9162, 11034]}
# {73: [7165, 2000]}
# {74: [11242, 2919]}
# {75: [571, 4309]}
# {76: [7982, 13521]}
# {77: [429, 8584]}
# {78: [10587, 2386]}
# {79: [15139, 13184]}
# {80: [3908, 13741]}
# {81: [2150, 1849]}
# {82: [2429, 2611]}
# {83: [8565, 12835]}
# {84: [7465, 6581]}
# {85: [10740, 4405]}
# {86: [2474, 3586]}
# {87: [4513, 3228]}
# {88: [3138, 9770]}
# {89: [9537, 5662]}
# {90: [9152, 5092]}
# {91: [15241, 808]}
# {92: [5223, 2521]}
# {93: [20, 420]}
# {94: [6531, 3584]}
# {95: [2516, 14061]}
# {96: [6378, 13064]}
# {97: [4531, 7757]}
# {98: [13391, 5022]}
# {99: [15260, 66]}
# {100: [8291, 7306]}
# {101: [7531, 13064]}
# {102: [15301, 6176]}
# {103: [1457, 4409]}
# {104: [8553, 5750]}
# {105: [14443, 11162]}
# {106: [14008, 13726]}
# {107: [14807, 404]}
# {108: [600, 3781]}
# {109: [2799, 14176]}
# {110: [6277, 5779]}
# {111: [7908, 7602]}
# {112: [1870, 819]}
# {113: [6289, 12907]}
# {114: [9766, 14858]}
# {115: [8007, 13223]}
# {116: [2062, 914]}
# {117: [15138, 2406]}
# {118: [12468, 4013]}
# {119: [10992, 11360]}
# {120: [1115, 1763]}
# {121: [8799, 6033]}
# {122: [12664, 12030]}
# {123: [9335, 6042]}
# {124: [10283, 6458]}
# {125: [5147, 14769]}
# {126: [13271, 595]}
# {127: [10599, 4617]}
# {128: [4788, 10053]}
# {129: [1114, 4760]}
# {130: [3986, 3702]}
# {131: [9881, 1413]}
# {132: [662, 2146]}
# {133: [4578, 6695]}
# {134: [1374, 2893]}
# {135: [451, 13222]}
# {136: [1380, 192]}
# {137: [1785, 3833]}
# {138: [2389, 2354]}
# {139: [9761, 11091]}
# {140: [8439, 1799]}
# {141: [8593, 9125]}
# {142: [6590, 13287]}
# {143: [12368, 13082]}
# {144: [3389, 6729]}
# {145: [5839, 4727]}
# {146: [3583, 4194]}
# {147: [13110, 10279]}
# {148: [7177, 9374]}
# {149: [1270, 5576]}
# {150: [6878, 11523]}
# {151: [1909, 6227]}
# {152: [12995, 8466]}
# {153: [7869, 14304]}
# {154: [10089, 9799]}
# {155: [6915, 1117]}
# {156: [8793, 10120]}
# {157: [11891, 10668]}
# {158: [11137, 8692]}
# {159: [11630, 9394]}
# {160: [3930, 6780]}
# {161: [11123, 12607]}
# {162: [8899, 4361]}
# {163: [10421, 12115]}
# {164: [6931, 8432]}
# {165: [5537, 10558]}
# {166: [3857, 13498]}
# {167: [3333, 4995]}
# {168: [9178, 9395]}
# {169: [3344, 10866]}
# {170: [8162, 8010]}
# {171: [6877, 13197]}
# {172: [13932, 14436]}
# {173: [4957, 9955]}
# {174: [12424, 14997]}
# {175: [11072, 4803]}
# {176: [5281, 789]}
# {177: [6165, 10322]}
# {178: [8940, 2835]}
# {179: [14540, 653]}
# {180: [103, 9129]}
# {181: [4494, 11800]}
# {182: [1642, 14500]}
# {183: [13818, 10879]}
# {184: [4875, 6074]}
# {185: [14743, 14937]}
# {186: [6683, 7906]}
# {187: [2138, 738]}
# {188: [14295, 1535]}
# {189: [7209, 3212]}
# {190: [9752, 826]}
# {191: [12133, 7783]}
# {192: [6407, 3219]}
# {193: [11287, 9932]}
# {194: [14420, 14065]}
# {195: [5310, 5541]}
# {196: [1215, 7601]}
# {197: [1404, 2249]}
# {198: [6499, 767]}
# {199: [629, 10515]}
# {200: [12478, 10089]}
# {201: [6605, 6436]}
# {202: [3859, 2596]}
# {203: [5606, 11303]}
# {204: [14673, 11192]}
# {205: [3064, 1506]}
# {206: [5795, 2303]}
# {207: [7215, 12263]}
# {208: [10030, 12751]}
# {209: [11047, 7261]}
# {210: [121, 4378]}
# {211: [8389, 5324]}
# {212: [11040, 1259]}
# {213: [12374, 10565]}
# {214: [6029, 6113]}
# {215: [10298, 9113]}
# {216: [12522, 6662]}
# {217: [10342, 14887]}
# {218: [11001, 9007]}
# {219: [11272, 5466]}
# {220: [267, 4389]}
# {221: [7241, 12550]}
# {222: [10449, 10193]}
# {223: [3384, 12920]}
# {224: [11883, 13349]}
# {225: [14684, 5809]}
# {226: [7537, 15164]}
# {227: [9393, 11560]}
# {228: [1551, 13296]}
# {229: [9532, 9822]}
# {230: [6160, 11132]}
# {231: [665, 8982]}
# {232: [564, 347]}
# {233: [9454, 12080]}
# {234: [5271, 11417]}
# {235: [14412, 7446]}
# {236: [13525, 1682]}
# {237: [8879, 4671]}
# {238: [14884, 1536]}
# {239: [5178, 15137]}
# {240: [13149, 9774]}
# {241: [3312, 12086]}
# {242: [13171, 14084]}
# {243: [12883, 5047]}
# {244: [6553, 14403]}
# {245: [6961, 6071]}
# {246: [14088, 11617]}
# {247: [11515, 9542]}
# {248: [4186, 12593]}
# {249: [6362, 12358]}
# {250: [10798, 6765]}
# {251: [2282, 4740]}
# {252: [12480, 5750]}
# {253: [10292, 14555]}
# {254: [4584, 2731]}
# {255: [2213, 13911]}
# {256: [6190, 2031]}
# {257: [1319, 9720]}
# {258: [5232, 522]}
# {259: [7615, 10122]}
# {260: [14223, 2028]}
# {261: [1922, 3983]}
# {262: [15239, 5293]}
# {263: [13748, 798]}
# {264: [7049, 268]}
# {265: [13210, 671]}
# {266: [1173, 5340]}
# {267: [12436, 8030]}
# {268: [14386, 8672]}
# {269: [8633, 6238]}
# {270: [5506, 9427]}
# {271: [6314, 7232]}
# {272: [8267, 12701]}
# {273: [6988, 9925]}
# {274: [10249, 1429]}
# {275: [3472, 8284]}
# {276: [13622, 8822]}
# {277: [6998, 10091]}
# {278: [11416, 12028]}
# {279: [10976, 2632]}
# {280: [11134, 731]}
# {281: [14607, 13228]}
# {282: [11229, 4910]}
# {283: [11419, 10210]}
# {284: [14707, 5442]}
# {285: [9222, 15291]}
# {286: [5705, 4528]}
# {287: [12113, 5077]}
# {288: [10713, 7555]}
# {289: [949, 1340]}
# {290: [1492, 2503]}
# {291: [7214, 10010]}
# {292: [13128, 7617]}
# {293: [3529, 10300]}
# {294: [12234, 10427]}
# {295: [8282, 944]}
# {296: [10914, 2704]}
# {297: [86, 9845]}
# {298: [12005, 385]}
# {299: [1194, 348]}
# {300: [6759, 3426]}
# {301: [12000, 12251]}
# {302: [12712, 13750]}
# {303: [3780, 11124]}
# {304: [339, 3069]}
# {305: [15160, 7126]}
# {306: [7729, 14201]}
# {307: [12961, 11618]}
# {308: [13970, 10496]}
# {309: [3160, 1628]}
# {310: [13857, 7298]}
# {311: [9374, 10847]}
# {312: [14064, 4964]}
# {313: [11451, 3497]}
# {314: [1182, 12237]}
# {315: [10154, 7085]}
# {316: [13347, 8744]}
# {317: [8522, 8512]}
# {318: [14696, 14299]}
# {319: [9923, 1833]}
# {320: [13858, 2279]}
# {321: [1555, 5254]}
# {322: [7756, 13995]}
# {323: [11090, 6753]}
# {324: [4665, 7363]}
# {325: [2158, 4990]}
# {326: [6840, 4055]}
# {327: [241, 11791]}
# {328: [4260, 10627]}
# {329: [2813, 11981]}
# {330: [4231, 15154]}
# {331: [4965, 3754]}
# {332: [8892, 3853]}
# {333: [14744, 5429]}
# {334: [3458, 10915]}
# {335: [12437, 8390]}
# {336: [4199, 4716]}
# {337: [14978, 6488]}
# {338: [6623, 13817]}
# {339: [10748, 3115]}
# {340: [1082, 13195]}
# {341: [6265, 9036]}
# {342: [6011, 12931]}
# {343: [3011, 8931]}
# {344: [9097, 6981]}
# {345: [8109, 8176]}
# {346: [6572, 8131]}
# {347: [5590, 14079]}
# {348: [6109, 1776]}
# {349: [6841, 10449]}
# {350: [6929, 10590]}
# {351: [14940, 4788]}
# {352: [26, 1647]}
# {353: [2460, 11392]}
# {354: [3157, 11150]}
# {355: [667, 377]}
# {356: [9593, 9563]}
# {357: [5906, 14785]}
# {358: [4653, 712]}
# {359: [702, 12275]}
# {360: [6906, 4787]}
# {361: [5169, 3214]}
# {362: [12069, 15039]}
# {363: [8395, 7292]}
# {364: [3408, 15260]}
# {365: [12602, 1376]}
# {366: [7771, 9592]}
# {367: [3029, 6909]}
# {368: [13778, 10983]}
# {369: [12689, 8040]}
# {370: [2704, 530]}
# {371: [9104, 11160]}
# {372: [7787, 1903]}
# {373: [10874, 6124]}
# {374: [10960, 10176]}
# {375: [6989, 8391]}
# {376: [11983, 5653]}
# {377: [11265, 8432]}
# {378: [15190, 5697]}
# {379: [994, 6631]}
# {380: [9016, 14569]}
# {381: [4074, 5410]}
# {382: [10195, 11311]}
# {383: [4483, 224]}
# {384: [8300, 14826]}
# {385: [7827, 11082]}
# {386: [12017, 9689]}
# {387: [12166, 4197]}
# {388: [9170, 3826]}
# {389: [244, 2766]}
# {390: [10412, 2324]}
# {391: [3056, 8769]}
# {392: [2302, 13546]}
# {393: [12867, 4427]}
# {394: [5034, 4647]}
# {395: [8794, 1238]}
# {396: [6309, 6894]}
# {397: [12215, 8527]}
# {398: [11453, 5142]}
# {399: [9260, 8891]}
# {400: [11588, 1616]}
# {401: [10900, 13467]}
# {402: [10368, 10951]}
# {403: [11526, 13773]}
# {404: [9478, 11301]}
# {405: [5575, 14753]}
# {406: [9876, 8189]}
# {407: [13919, 5473]}
# {408: [8690, 7160]}
# {409: [5624, 492]}
# {410: [6043, 9726]}
# {411: [6429, 9528]}
# {412: [2316, 9843]}
# {413: [6769, 15021]}
# {414: [9873, 863]}
# {415: [14894, 10689]}
# {416: [3142, 14493]}
# {417: [1048, 9229]}
# {418: [2796, 10492]}
# {419: [1361, 14661]}
# {420: [12956, 7139]}
# {421: [886, 724]}
# {422: [13960, 12281]}
# {423: [11266, 5170]}
# {424: [11213, 6786]}
# {425: [62, 1307]}
# {426: [2123, 8677]}
# {427: [1103, 11440]}
# {428: [8658, 10091]}
# {429: [10418, 8623]}
# {430: [413, 10913]}
# {431: [1901, 8892]}
# {432: [1358, 3055]}
# {433: [3008, 13988]}
# {434: [13344, 4965]}
# {435: [14126, 13462]}
# {436: [5994, 13944]}
# {437: [6501, 12771]}
# {438: [14829, 14708]}
# {439: [2817, 3905]}
# {440: [10319, 6949]}
# {441: [10955, 3691]}
# {442: [13954, 13818]}
# {443: [3989, 6770]}
# {444: [14493, 7544]}
# {445: [7320, 7404]}
# {446: [8809, 11997]}
# {447: [10271, 12218]}
# {448: [13424, 11855]}
# {449: [13177, 2271]}
# {450: [10922, 3490]}
# {451: [4871, 8195]}
# {452: [7479, 9154]}
# {453: [14869, 8974]}
# {454: [7054, 3436]}
# {455: [13833, 13523]}
# {456: [6846, 2973]}
# {457: [7183, 13258]}
# {458: [10721, 4638]}
# {459: [7065, 1163]}
# {460: [12506, 562]}
# {461: [171, 9311]}
# {462: [5189, 3056]}
# {463: [2880, 8751]}
# {464: [11197, 12703]}
# {465: [15297, 5052]}
# {466: [13706, 11493]}
# {467: [3419, 12181]}
# {468: [5783, 14979]}
# {469: [8531, 300]}
# {470: [7292, 5365]}
# {471: [346, 11503]}
# {472: [13204, 2827]}
# {473: [6464, 5677]}
# {474: [2469, 12770]}
# {475: [9817, 14383]}
# {476: [4968, 360]}
# {477: [8844, 517]}
# {478: [10445, 9284]}
# {479: [1714, 14336]}
# {480: [6942, 1477]}
# {481: [13470, 4531]}
# {482: [14718, 9986]}
# {483: [15296, 10043]}
# {484: [3631, 8791]}
# {485: [554, 8936]}
# {486: [8612, 5866]}
# {487: [3179, 12465]}
# {488: [13686, 12851]}
# {489: [13324, 12627]}
# {490: [9342, 13082]}
# {491: [10532, 6027]}
# {492: [12317, 701]}
# {493: [10043, 8440]}
# {494: [14664, 14779]}
# {495: [11320, 14835]}
# {496: [9784, 2103]}
# {497: [12422, 11463]}
# {498: [8290, 529]}
# {499: [6743, 3570]}
# {500: [8252, 6407]}
# {501: [11696, 2584]}
# {502: [14973, 4995]}
# {503: [3236, 10941]}
# {504: [1107, 10990]}
# {505: [2034, 8188]}
# {506: [11463, 7805]}
# {507: [10716, 12070]}
# {508: [11048, 15118]}
# {509: [4558, 11045]}
# {510: [10027, 13200]}
# {511: [5067, 9423]}
# {512: [2314, 10846]}
# {513: [5535, 12006]}
# {514: [1906, 5708]}
# {515: [4247, 10065]}
# {516: [13934, 288]}
# {517: [3319, 10706]}
# {518: [10564, 3679]}
# {519: [9281, 2495]}
# {520: [616, 5336]}
# {521: [28, 3581]}
# {522: [10474, 2107]}
# {523: [13721, 1045]}
# {524: [3133, 12424]}
# {525: [13808, 10606]}
# {526: [10071, 3487]}
# {527: [1715, 58]}
# {528: [1803, 11386]}
# {529: [4633, 5542]}
# {530: [10266, 11755]}
# {531: [9065, 8803]}
# {532: [8024, 4745]}
# {533: [4048, 2052]}
# {534: [6026, 4606]}
# {535: [1753, 6701]}
# {536: [1567, 1102]}
# {537: [8651, 808]}
# {538: [3002, 9053]}
# {539: [606, 4258]}
# {540: [12765, 11830]}
# {541: [12430, 6881]}
# {542: [11986, 14896]}
# {543: [7958, 5806]}
# {544: [12148, 2674]}
# {545: [6985, 13931]}
# {546: [3010, 13647]}
# {547: [12494, 13450]}
# {548: [6868, 6437]}
# {549: [7857, 1066]}
# {550: [15078, 8911]}
# {551: [10387, 13889]}
# {552: [495, 15082]}
# {553: [9468, 2075]}
# {554: [14143, 10830]}
# {555: [1947, 9277]}
# {556: [10441, 12952]}
# {557: [9605, 3954]}
# {558: [4641, 2046]}
# {559: [12397, 9716]}
# {560: [7994, 13657]}
# {561: [7515, 12794]}
# {562: [11586, 9367]}
# {563: [9291, 3398]}
# {564: [3676, 15171]}
# {565: [5702, 14671]}
# {566: [8616, 5352]}
# {567: [2424, 13706]}
# {568: [2776, 7467]}
# {569: [414, 996]}
# {570: [3864, 11734]}
# {571: [10777, 967]}
# {572: [1262, 5576]}
# {573: [15304, 3489]}
# {574: [14235, 6626]}
# {575: [4690, 7357]}
# {576: [11622, 8657]}
# {577: [4429, 14010]}
# {578: [1121, 10411]}
# {579: [9047, 9460]}
# {580: [11525, 3920]}
# {581: [5341, 5424]}
# {582: [15045, 5498]}
# {583: [7761, 3383]}
# {584: [12539, 2460]}
# {585: [14445, 2503]}
# {586: [8242, 12653]}
# {587: [14199, 12184]}
# {588: [175, 8089]}
# {589: [14409, 5266]}
# {590: [6554, 2852]}
# {591: [3455, 4099]}
# {592: [1826, 8389]}
# {593: [12150, 14267]}
# {594: [1919, 5476]}
# {595: [1731, 6649]}
# {596: [10117, 10473]}
# {597: [9744, 5974]}
# {598: [2774, 2370]}
# {599: [11478, 1542]}
# {600: [2221, 9326]}
# {601: [9758, 11512]}
# {602: [12849, 11733]}
# {603: [12928, 9539]}
# {604: [14850, 12675]}
# {605: [4841, 7227]}
# {606: [14059, 5941]}
# {607: [165, 10849]}
# {608: [5953, 8050]}
# {609: [12371, 7007]}
# {610: [6128, 3619]}
# {611: [7367, 11485]}
# {612: [10869, 11399]}
# {613: [5877, 10980]}
# {614: [10363, 14772]}
# {615: [8403, 1419]}
# {616: [1124, 616]}
# {617: [12562, 13256]}
# {618: [8819, 9119]}
# {619: [12718, 5561]}
# {620: [14166, 713]}
# {621: [2375, 13678]}
# {622: [8435, 5025]}
# {623: [11610, 8949]}
# {624: [1324, 3855]}
# {625: [5433, 15054]}
# {626: [9551, 9678]}
# {627: [2757, 6953]}
# {628: [6734, 14505]}
# {629: [13958, 8]}
# {630: [3387, 13301]}
# {631: [7341, 7589]}
# {632: [10180, 613]}
# {633: [8916, 2231]}
# {634: [13663, 6471]}
# {635: [10141, 6913]}
# {636: [13077, 10405]}
# {637: [13359, 10669]}
# {638: [7026, 1098]}
# {639: [5001, 5247]}
# {640: [8116, 9731]}
# {641: [14715, 3106]}
# {642: [3716, 4889]}
# {643: [6596, 743]}
# {644: [4716, 1272]}
# {645: [2831, 7559]}
# {646: [4061, 9023]}
# {647: [1286, 2934]}
# {648: [11603, 10192]}
# {649: [3635, 9041]}
# {650: [11512, 8317]}
# {651: [14252, 3188]}
# {652: [10160, 58]}
# {653: [12792, 11397]}
# {654: [8504, 4006]}
# {655: [7676, 7268]}
# {656: [13045, 4910]}
# {657: [8226, 11011]}
# {658: [9377, 1911]}
# {659: [1965, 13264]}
# {660: [13264, 4683]}
# {661: [4542, 9120]}
# {662: [7969, 13999]}
# {663: [7318, 11371]}
# {664: [9643, 7723]}
# {665: [10801, 2070]}
# {666: [6509, 9355]}
# {667: [14610, 1602]}
# {668: [8766, 4800]}
# {669: [12320, 10318]}
# {670: [5090, 568]}
# {671: [4217, 674]}
# {672: [13826, 9174]}
# {673: [2397, 301]}
# {674: [5129, 13890]}
# {675: [14471, 5862]}
# {676: [4519, 1023]}
# {677: [1499, 10832]}
# {678: [7775, 1889]}
# {679: [1223, 12103]}
# {680: [14332, 13205]}
# {681: [9043, 4039]}
# {682: [5971, 11467]}
# {683: [4978, 950]}
# {684: [3733, 7234]}
# {685: [14800, 872]}
# {686: [9916, 2200]}
# {687: [15015, 14264]}
# {688: [1352, 9113]}
# {689: [4833, 12846]}
# {690: [14681, 8601]}
# {691: [864, 8724]}
# {692: [12869, 10863]}
# {693: [9068, 13256]}
# {694: [15155, 13995]}
# {695: [1059, 8806]}
# {696: [12396, 10003]}
# {697: [7246, 10295]}
# {698: [1145, 936]}
# {699: [10608, 10487]}
# {700: [6822, 6282]}
# {701: [283, 14307]}
# {702: [1307, 2044]}
# {703: [10495, 8577]}
# {704: [10559, 9419]}
# {705: [14970, 5222]}
# {706: [13318, 6502]}
# {707: [14767, 9666]}
# {708: [14005, 10048]}
# {709: [1133, 5208]}
# {710: [15086, 15263]}
# {711: [6628, 5010]}
# {712: [11024, 9982]}
# {713: [10166, 4568]}
# {714: [2526, 3815]}
# {715: [1322, 10168]}
# {716: [13213, 10098]}
# {717: [14277, 3583]}
# {718: [5746, 4536]}
# {719: [14846, 5596]}
# {720: [9988, 6609]}
# {721: [12781, 9737]}
# {722: [2949, 1442]}
# {723: [1397, 13459]}
# {724: [12009, 576]}
# {725: [12194, 10101]}
# {726: [13899, 14610]}
# {727: [6603, 5818]}
# {728: [3617, 3981]}
# {729: [11060, 3807]}
# {730: [104, 10442]}
# {731: [14832, 7038]}
# {732: [1388, 1553]}
# {733: [181, 9531]}
# {734: [10484, 8784]}
# {735: [4137, 12869]}
# {736: [9844, 9865]}
# {737: [9127, 2219]}
# {738: [8597, 10270]}
# {739: [10325, 12701]}
# {740: [13786, 7587]}
# {741: [4655, 4867]}
# {742: [6807, 14461]}
# {743: [1258, 11316]}
# {744: [9159, 4396]}
# {745: [5334, 13639]}
# {746: [2173, 10056]}
# {747: [12395, 4475]}
# {748: [3783, 9383]}
# {749: [11598, 14564]}
# {750: [1546, 13181]}
# {751: [3216, 7147]}
# {752: [2628, 1875]}
# {753: [11114, 10626]}
# {754: [6009, 9317]}
# {755: [4632, 7760]}
# {756: [6888, 1998]}
# {757: [2045, 4184]}
# {758: [7546, 90]}
# {759: [10090, 13952]}
# {760: [15242, 4705]}
# {761: [9727, 12623]}
# {762: [1907, 13128]}
# {763: [15005, 9019]}
# {764: [7068, 1328]}
# {765: [6806, 3323]}
# {766: [10236, 12280]}
# {767: [14487, 4544]}
# {768: [12786, 2224]}
# {769: [10440, 2843]}
# {770: [2672, 8368]}
# {771: [13326, 14432]}
# {772: [1515, 12034]}
# {773: [4277, 7171]}
# {774: [10668, 8472]}
# {775: [4386, 1346]}
# {776: [5951, 830]}
# {777: [14558, 2887]}
# {778: [13588, 6202]}
# {779: [8911, 5204]}
# {780: [4415, 9181]}
# {781: [6197, 13449]}
# {782: [6924, 11093]}
# {783: [13692, 4472]}
# {784: [9921, 4494]}
# {785: [12212, 10683]}
# {786: [8261, 13661]}
# {787: [7943, 6527]}
# {788: [10531, 6474]}
# {789: [9648, 4008]}
# {790: [12917, 3403]}
# {791: [13286, 14076]}
# {792: [9239, 12348]}
# {793: [5021, 4077]}
# {794: [11853, 7378]}
# {795: [7898, 2632]}
# {796: [9158, 10638]}
# {797: [9293, 13496]}
# {798: [14021, 8505]}
# {799: [1892, 14023]}
# {800: [6204, 5313]}
# {801: [8040, 11786]}
# {802: [12216, 1432]}
# {803: [3331, 4253]}
# {804: [262, 13455]}
# {805: [326, 2704]}
# {806: [5661, 5780]}
# {807: [2406, 10634]}
# {808: [7978, 3462]}
# {809: [13892, 846]}
# {810: [2888, 1732]}
# {811: [12978, 2733]}
# {812: [1491, 2008]}
# {813: [14547, 14235]}
# {814: [5015, 1645]}
# {815: [6490, 14413]}
# {816: [1233, 15128]}
# {817: [8047, 12]}
# {818: [11550, 7709]}
# {819: [14089, 14180]}
# {820: [2171, 3057]}
# {821: [13055, 1567]}
# {822: [3681, 8997]}
# {823: [11602, 3199]}
# {824: [7506, 3563]}
# {825: [1755, 6057]}
# {826: [14367, 8307]}
# {827: [6982, 2339]}
# {828: [7046, 6465]}
# {829: [2007, 14677]}
# {830: [2827, 8065]}
# {831: [1791, 6830]}
# {832: [13164, 10898]}
# {833: [10016, 12908]}
# {834: [5638, 13028]}
# {835: [1734, 7428]}
# {836: [12680, 5143]}
# {837: [1377, 1947]}
# {838: [12307, 4537]}
# {839: [14497, 11572]}
# {840: [230, 5822]}
# {841: [14543, 1539]}
# {842: [8969, 5807]}
# {843: [67, 11620]}
# {844: [13553, 8712]}
# {845: [1705, 6408]}
# {846: [11732, 8102]}
# {847: [2197, 13303]}
# {848: [1833, 6071]}
# {849: [8037, 7856]}
# {850: [523, 13648]}
# {851: [11569, 6634]}
# {852: [14804, 8767]}
# {853: [9358, 9345]}
# {854: [11653, 9319]}
# {855: [2226, 14595]}
# {856: [14111, 9094]}
# {857: [9403, 15066]}
# {858: [8412, 14584]}
# {859: [14887, 6741]}
# {860: [5315, 11599]}
# {861: [1821, 6477]}
# {862: [8878, 574]}
# {863: [14534, 5901]}
# {864: [6656, 5281]}
# {865: [7122, 3058]}
# {866: [14837, 1604]}
# {867: [7535, 9400]}
# {868: [6794, 9016]}
# {869: [4480, 12434]}
# {870: [2538, 11310]}
# {871: [10714, 2756]}
# {872: [3659, 15062]}
# {873: [942, 735]}
# {874: [8139, 9035]}
# {875: [14689, 12810]}
# {876: [5041, 15300]}
# {877: [14857, 3364]}
# {878: [4078, 10942]}
# {879: [2540, 4662]}
# {880: [785, 7102]}
# {881: [10429, 3149]}
# {882: [7208, 2856]}
# {883: [12587, 5963]}
# {884: [5751, 3813]}
# {885: [14668, 2917]}
# {886: [12583, 3520]}
# {887: [14582, 657]}
# {888: [7579, 6430]}
# {889: [159, 1164]}
# {890: [6908, 2282]}
# {891: [307, 15226]}
# {892: [5087, 8184]}
# {893: [935, 9848]}
# {894: [2565, 10427]}
# {895: [10149, 4028]}
# {896: [5079, 10743]}
# {897: [9295, 8804]}
# {898: [4468, 13620]}
# {899: [4194, 9062]}
# {900: [6651, 13616]}
# {901: [6141, 4102]}
# {902: [8156, 3728]}
# {903: [3663, 6200]}
# {904: [70, 4896]}
# {905: [9706, 5488]}
# {906: [1508, 3407]}
# {907: [1393, 4179]}
# {908: [8557, 8067]}
# {909: [7521, 4672]}
# {910: [8706, 11439]}
# {911: [3751, 3401]}
# {912: [5924, 12594]}
# {913: [105, 1462]}
# {914: [11277, 11345]}
# {915: [8172, 2742]}
# {916: [7743, 5907]}
# {917: [8913, 10249]}
# {918: [5158, 12736]}
# {919: [6675, 415]}
# {920: [5439, 3992]}
# {921: [4459, 305]}
# {922: [7772, 386]}
# {923: [13366, 12651]}
# {924: [13349, 2870]}
# {925: [9903, 586]}
# {926: [4413, 6917]}
# {927: [3607, 56]}
# {928: [5708, 10416]}
# {929: [10585, 4172]}
# {930: [12598, 3188]}
# {931: [6618, 4134]}
# {932: [2901, 8558]}
# {933: [652, 7240]}
# {934: [12208, 11145]}
# {935: [12137, 13179]}
# {936: [9318, 4923]}
# {937: [924, 14149]}
# {938: [6352, 10403]}
# {939: [10424, 7661]}
# {940: [1013, 13849]}
# {941: [1481, 3768]}
# {942: [12519, 6333]}
# {943: [6253, 8003]}
# {944: [14578, 3126]}
# {945: [11532, 5054]}
# {946: [5337, 4703]}
# {947: [492, 10808]}
# {948: [11176, 7709]}
# {949: [12120, 11234]}
# {950: [4254, 2657]}
# {951: [12257, 5195]}
# {952: [3186, 1739]}
# {953: [11682, 1857]}
# {954: [14429, 8504]}
# {955: [740, 11589]}
# {956: [7101, 5531]}
# {957: [12693, 8575]}
# {958: [12485, 7585]}
# {959: [6708, 14063]}
# {960: [13392, 9021]}
# {961: [9066, 3328]}
# {962: [1071, 10613]}
# {963: [5997, 3213]}
# {964: [13358, 5384]}
# {965: [14727, 11499]}
# {966: [3108, 13074]}
# {967: [3348, 5132]}
# {968: [12401, 7086]}
# {969: [6193, 2970]}
# {970: [8473, 2190]}
# {971: [8209, 3486]}
# {972: [2645, 6646]}
# {973: [2582, 13893]}
# {974: [12172, 472]}
# {975: [4902, 11449]}
# {976: [5462, 9539]}
# {977: [10701, 9216]}
# {978: [12745, 4876]}
# {979: [3911, 9813]}
# {980: [9788, 11308]}
# {981: [10084, 6630]}
# {982: [1793, 4081]}
# {983: [4764, 663]}
# {984: [179, 4983]}
# {985: [4059, 1161]}
# {986: [8691, 12841]}
# {987: [14671, 7881]}
# {988: [1037, 8157]}
# {989: [4603, 11026]}
# {990: [196, 14970]}
# {991: [1208, 7732]}
# {992: [9875, 5172]}
# {993: [5039, 9706]}
# {994: [10345, 11389]}
# {995: [13501, 9600]}
# {996: [6286, 584]}
# {997: [13118, 4923]}
# {998: [12942, 13858]}
# {999: [5976, 15245]}
# {1000: [7190, 2557]}
# {1001: [6577, 1929]}
# {1002: [9804, 9649]}
# {1003: [3356, 524]}
# {1004: [6522, 13240]}
# {1005: [5723, 7662]}
# {1006: [11199, 14948]}
# {1007: [10627, 2708]}
# {1008: [13992, 9140]}
# {1009: [5104, 1488]}
# {1010: [11145, 10542]}
# {1011: [12034, 2612]}
# {1012: [3547, 7475]}
# {1013: [12622, 8488]}
# {1014: [6226, 7913]}
# {1015: [11607, 9638]}
# {1016: [7715, 1318]}
# {1017: [854, 826]}
# {1018: [13207, 13057]}
# {1019: [9595, 4190]}
# {1020: [5394, 10482]}
# {1021: [1267, 11377]}
# {1022: [7935, 2545]}
# {1023: [13964, 2696]}
# {1024: [2833, 2318]}
# {1025: [3082, 2555]}
# {1026: [9538, 9876]}
# {1027: [5589, 9260]}
# {1028: [7405, 9691]}
# {1029: [1545, 8550]}
# {1030: [4169, 12677]}
# {1031: [454, 2354]}
# {1032: [4806, 11459]}
# {1033: [14847, 2544]}
# {1034: [8414, 11788]}
# {1035: [145, 6487]}
# {1036: [4706, 2775]}
# {1037: [13779, 11818]}
# {1038: [3630, 6209]}
# {1039: [703, 5386]}
# {1040: [3904, 5458]}
# {1041: [6565, 1987]}
# {1042: [9451, 14460]}
# {1043: [14994, 3770]}
# {1044: [1577, 14109]}
# {1045: [14813, 793]}
# {1046: [7002, 1787]}
# {1047: [13863, 11369]}
# {1048: [9202, 12954]}
# {1049: [12591, 2688]}
# {1050: [14640, 7967]}
# {1051: [845, 5758]}
# {1052: [10769, 3331]}
# {1053: [14773, 554]}
# {1054: [1936, 8938]}
# {1055: [777, 10713]}
# {1056: [4124, 9783]}
# {1057: [3261, 8323]}
# {1058: [9072, 8908]}
# {1059: [15299, 1326]}
# {1060: [9504, 11919]}
# {1061: [11537, 3902]}
# {1062: [15120, 4664]}
# {1063: [3233, 7753]}
# {1064: [8849, 14828]}
# {1065: [2141, 13170]}
# {1066: [8032, 696]}
# {1067: [13168, 10512]}
# {1068: [12626, 3321]}
# {1069: [15002, 8005]}
# {1070: [11111, 4654]}
# {1071: [5128, 2600]}
# {1072: [6389, 1655]}
# {1073: [4566, 3229]}
# {1074: [11752, 12681]}
# {1075: [6462, 5875]}
# {1076: [9341, 1772]}
# {1077: [14264, 4544]}
# {1078: [8497, 8030]}
# {1079: [11251, 1800]}
# {1080: [13380, 816]}
# {1081: [5475, 14273]}
# {1082: [5967, 15000]}
# {1083: [14004, 1736]}
# {1084: [1221, 14513]}
# {1085: [8826, 14087]}
# {1086: [1219, 4800]}
# {1087: [13252, 9276]}
# {1088: [6902, 3506]}
# {1089: [14596, 9052]}
# {1090: [11747, 5674]}
# {1091: [276, 11157]}
# {1092: [4377, 13368]}
# {1093: [6519, 9242]}
# {1094: [14204, 14973]}
# {1095: [7429, 8751]}
# {1096: [6873, 6674]}
# {1097: [9732, 9705]}
# {1098: [10358, 6985]}
# {1099: [15230, 7382]}
# {1100: [524, 6001]}
# {1101: [4073, 12609]}
# {1102: [12347, 14448]}
# {1103: [876, 4808]}
# {1104: [2550, 1145]}
# {1105: [7587, 3139]}
# {1106: [12472, 7288]}
# {1107: [10724, 6988]}
# {1108: [10991, 8006]}
# {1109: [14349, 6423]}
# {1110: [10018, 3012]}
# {1111: [12407, 6533]}
# {1112: [12913, 173]}
# {1113: [8734, 988]}
# {1114: [13718, 4315]}
# {1115: [6267, 7731]}
# {1116: [525, 11538]}
# {1117: [2143, 5834]}
# {1118: [13499, 2039]}
# {1119: [12696, 10125]}
# {1120: [14566, 5208]}
# {1121: [12848, 10973]}
# {1122: [2529, 3425]}
# {1123: [1406, 10267]}
# {1124: [6957, 2257]}
# {1125: [7034, 6202]}
# {1126: [3910, 13745]}
# {1127: [8013, 8180]}
# {1128: [8215, 578]}
# {1129: [1301, 3985]}
# {1130: [13986, 579]}
# {1131: [2095, 7557]}
# {1132: [555, 3582]}
# {1133: [8125, 1281]}
# {1134: [12935, 12456]}
# {1135: [542, 4705]}
# {1136: [7773, 6180]}
# {1137: [5190, 10244]}
# {1138: [8894, 7300]}
# {1139: [377, 7943]}
# {1140: [6, 2830]}
# {1141: [8318, 13522]}
# {1142: [11, 1516]}
# {1143: [1284, 3888]}
# {1144: [4723, 2152]}
# {1145: [6273, 7316]}
# {1146: [2834, 1019]}
# {1147: [8179, 13706]}
# {1148: [9624, 5172]}
# {1149: [13605, 8358]}
# {1150: [1149, 432]}
# {1151: [2219, 7147]}
# {1152: [4784, 13931]}
# {1153: [1473, 12613]}
# {1154: [2606, 13812]}
# {1155: [12686, 9313]}
# {1156: [1274, 2094]}
# {1157: [12613, 7243]}
# {1158: [10806, 13083]}
# {1159: [8848, 415]}
# {1160: [10497, 8505]}
# {1161: [459, 124]}
# {1162: [8704, 4366]}
# {1163: [14198, 11390]}
# {1164: [1326, 9635]}
# {1165: [10565, 9249]}
# {1166: [8075, 1754]}
# {1167: [10756, 15018]}
# {1168: [7268, 9345]}
# {1169: [12470, 12959]}
# {1170: [8665, 6860]}
# {1171: [7139, 7402]}
# {1172: [10816, 2397]}
# {1173: [6948, 5995]}
# {1174: [14362, 10268]}
# {1175: [201, 12997]}
# {1176: [11316, 7908]}
# {1177: [1690, 6198]}
# {1178: [8823, 9854]}
# {1179: [3438, 15255]}
# {1180: [6954, 6660]}
# {1181: [251, 4603]}
# {1182: [10546, 11954]}
# {1183: [7393, 6582]}
# {1184: [11269, 3501]}
# {1185: [7627, 7178]}
# {1186: [7227, 11606]}
# {1187: [6365, 10025]}
# {1188: [514, 4886]}
# {1189: [10374, 6959]}
# {1190: [12845, 2501]}
# {1191: [12420, 5247]}
# {1192: [710, 1469]}
# {1193: [4612, 6580]}
# {1194: [132, 6860]}
# {1195: [14584, 2728]}
# {1196: [11677, 11595]}
# {1197: [5162, 11059]}
# {1198: [6658, 7220]}
# {1199: [11389, 11195]}
# {1200: [6893, 8650]}
# {1201: [5016, 6115]}
# {1202: [5989, 840]}
# {1203: [9546, 11921]}
# {1204: [6299, 5701]}
# {1205: [3758, 8323]}
# {1206: [7499, 9703]}
# {1207: [4707, 14487]}
# {1208: [14915, 11394]}
# {1209: [183, 11547]}
# {1210: [2533, 305]}
# {1211: [6638, 15141]}
# {1212: [8915, 11150]}
# {1213: [5897, 2347]}
# {1214: [10696, 5227]}
# {1215: [10237, 4890]}
# {1216: [6136, 9116]}
# {1217: [8590, 1061]}
# {1218: [737, 1373]}
# {1219: [9464, 1517]}
# {1220: [8411, 13245]}
# {1221: [8437, 7120]}
# {1222: [10489, 2099]}
# {1223: [4205, 3007]}
# {1224: [8965, 12022]}
# {1225: [9021, 20]}
# {1226: [7375, 3078]}
# {1227: [2904, 11782]}
# {1228: [6856, 1255]}
# {1229: [11861, 2039]}
# {1230: [8546, 7394]}
# {1231: [10252, 9552]}
# {1232: [5666, 1820]}
# {1233: [9294, 7856]}
# {1234: [11959, 14913]}
# {1235: [7804, 4898]}
# {1236: [2201, 138]}
# {1237: [8721, 2943]}
# {1238: [2071, 10383]}
# {1239: [15232, 9032]}
# {1240: [8680, 4725]}
# {1241: [12384, 13412]}
# {1242: [12820, 12441]}
# {1243: [14880, 6692]}
# {1244: [7299, 11706]}
# {1245: [11045, 8051]}
# {1246: [6756, 11852]}
# {1247: [8046, 9320]}
# {1248: [2785, 996]}
# {1249: [5894, 1410]}
# {1250: [4501, 7268]}
# {1251: [4855, 501]}
# {1252: [2584, 3911]}
# {1253: [696, 3180]}
# {1254: [15293, 3390]}
# {1255: [11637, 1859]}
# {1256: [6361, 7710]}
# {1257: [10065, 5163]}
# {1258: [6122, 13866]}
# {1259: [5725, 8207]}
# {1260: [3065, 4725]}
# {1261: [13040, 2131]}
# {1262: [5913, 10285]}
# {1263: [3905, 10635]}
# {1264: [3639, 5893]}
# {1265: [191, 8625]}
# {1266: [12316, 9472]}
# {1267: [3146, 3355]}
# {1268: [4526, 6610]}
# {1269: [14282, 4311]}
# {1270: [4024, 9879]}
# {1271: [4881, 10275]}
# {1272: [10150, 7000]}
# {1273: [3872, 4077]}
# {1274: [12681, 12403]}
# {1275: [6460, 1508]}
# {1276: [2352, 7893]}
# {1277: [1387, 11713]}
# {1278: [8572, 9079]}
# {1279: [10303, 14114]}
# {1280: [7750, 13388]}
# {1281: [12282, 4534]}
# {1282: [12256, 2279]}
# {1283: [5027, 32]}
# {1284: [10099, 5463]}
# {1285: [4223, 14695]}
# {1286: [5290, 7450]}
# {1287: [14639, 8859]}
# {1288: [8064, 7991]}
# {1289: [4679, 14470]}
# {1290: [3270, 13809]}
# {1291: [12459, 328]}
# {1292: [12921, 14469]}
# {1293: [4224, 4768]}
# {1294: [2972, 10351]}
# {1295: [11566, 4019]}
# {1296: [6602, 690]}
# {1297: [4042, 14010]}
# {1298: [2327, 11650]}
# {1299: [12165, 13168]}
# {1300: [11043, 9404]}
# {1301: [13988, 14604]}
# {1302: [7258, 1609]}
# {1303: [6911, 8018]}
# {1304: [4229, 2747]}
# {1305: [1061, 3902]}
# {1306: [8802, 1143]}
# {1307: [13453, 9044]}
# {1308: [3059, 11014]}
# {1309: [1268, 4105]}
# {1310: [8996, 2057]}
# {1311: [13693, 5839]}
# {1312: [6571, 2897]}
# {1313: [11364, 9298]}
# {1314: [3762, 13146]}
# {1315: [4763, 11008]}
# {1316: [1654, 3001]}
# {1317: [5635, 2774]}
# {1318: [8128, 7237]}
# {1319: [15143, 14056]}
# {1320: [5934, 13512]}
# {1321: [14868, 8205]}
# {1322: [13433, 13319]}
# {1323: [8136, 9508]}
# {1324: [2170, 2534]}
# {1325: [2664, 3112]}
# {1326: [6863, 13194]}
# {1327: [5227, 4850]}
# {1328: [7481, 8488]}
# {1329: [15223, 5632]}
# {1330: [1246, 12540]}
# {1331: [8262, 13725]}
# {1332: [9972, 3368]}
# {1333: [6217, 10442]}
# {1334: [11183, 5967]}
# {1335: [6714, 8604]}
# {1336: [15030, 10495]}
# {1337: [10751, 4122]}
# {1338: [8840, 2663]}
# {1339: [3568, 4725]}
# {1340: [458, 15201]}
# {1341: [4672, 6608]}
# {1342: [21, 96]}
# {1343: [10908, 2392]}
# {1344: [13761, 3125]}
# {1345: [9693, 7283]}
# {1346: [277, 7048]}
# {1347: [4556, 14805]}
# {1348: [5642, 5970]}
# {1349: [11773, 1084]}
# {1350: [8758, 1465]}
# {1351: [2700, 8852]}
# {1352: [9672, 5216]}
# {1353: [9080, 1556]}
# {1354: [12557, 9763]}
# {1355: [4819, 7865]}
# {1356: [13162, 7535]}
# {1357: [50, 12165]}
# {1358: [11051, 14300]}
# {1359: [11243, 8220]}
# {1360: [8298, 2908]}
# {1361: [13576, 13650]}
# {1362: [9366, 8523]}
# {1363: [10808, 15123]}
# {1364: [8224, 10269]}
# {1365: [1916, 10230]}
# {1366: [7316, 6249]}
# {1367: [421, 1952]}
# {1368: [13372, 10716]}
# {1369: [3262, 6592]}
# {1370: [7097, 3544]}
# {1371: [2331, 2234]}
# {1372: [1667, 88]}
# {1373: [7797, 12904]}
# {1374: [12387, 998]}
# {1375: [12469, 14372]}
# {1376: [1805, 14490]}
# {1377: [12599, 13037]}
# {1378: [13637, 13403]}
# {1379: [1994, 5751]}
# {1380: [10131, 14257]}
# {1381: [10853, 271]}
# {1382: [5387, 5758]}
# {1383: [65, 10632]}
# {1384: [4146, 7195]}
# {1385: [14403, 12333]}
# {1386: [162, 759]}
# {1387: [10971, 9368]}
# {1388: [3466, 665]}
# {1389: [8887, 13259]}
# {1390: [8240, 9353]}
# {1391: [152, 869]}
# {1392: [725, 3751]}
# {1393: [10568, 6699]}
# {1394: [7202, 8705]}
# {1395: [7290, 1153]}
# {1396: [7352, 10842]}
# {1397: [10638, 3540]}
# {1398: [1929, 3065]}
# {1399: [11896, 11509]}
# {1400: [7374, 7315]}
# {1401: [5164, 9427]}
# {1402: [8402, 3763]}
# {1403: [8346, 12252]}
# {1404: [4087, 1431]}
# {1405: [11209, 5625]}
# {1406: [9081, 5758]}
# {1407: [1954, 11434]}
# {1408: [3937, 10049]}
# {1409: [5846, 330]}
# {1410: [4358, 10849]}
# {1411: [1421, 557]}
# {1412: [9249, 2827]}
# {1413: [3803, 4214]}
# {1414: [3207, 82]}
# {1415: [9063, 1421]}
# {1416: [5044, 6973]}
# {1417: [13230, 11733]}
# {1418: [11224, 12590]}
# {1419: [6035, 14708]}
# {1420: [10734, 1043]}
# {1421: [14378, 8849]}
# {1422: [10050, 5685]}
# {1423: [11655, 5314]}
# {1424: [2058, 13134]}
# {1425: [7853, 9920]}
# {1426: [3731, 7735]}
# {1427: [5463, 7715]}
# {1428: [14820, 9481]}
# {1429: [11421, 7623]}
# {1430: [11217, 10859]}
# {1431: [4218, 2016]}
# {1432: [4885, 3280]}
# {1433: [9387, 14803]}
# {1434: [3424, 4361]}
# {1435: [13057, 12493]}
# {1436: [8443, 8310]}
# {1437: [10887, 2976]}
# {1438: [603, 14644]}
# {1439: [13646, 6384]}
# {1440: [11306, 13556]}
# {1441: [11296, 7749]}
# {1442: [2472, 10636]}
# {1443: [15184, 13437]}
# {1444: [12619, 7799]}
# {1445: [1384, 3776]}
# {1446: [10073, 12375]}
# {1447: [12806, 3481]}
# {1448: [11230, 3935]}
# {1449: [10047, 13115]}
# {1450: [11557, 7836]}
# {1451: [9539, 13356]}
# {1452: [7638, 8305]}
# {1453: [12116, 7469]}
# {1454: [11429, 5812]}
# {1455: [5349, 14246]}
# {1456: [11258, 10197]}
# {1457: [14394, 9004]}
# {1458: [13952, 7743]}
# {1459: [7090, 7746]}
# {1460: [12517, 868]}
# {1461: [13908, 5092]}
# {1462: [3318, 717]}
# {1463: [6521, 3630]}
# {1464: [4779, 2623]}
# {1465: [4244, 13011]}
# {1466: [13800, 7940]}
# {1467: [6034, 5542]}
# {1468: [7820, 9176]}
# {1469: [6397, 11467]}
# {1470: [8742, 9664]}
# {1471: [15061, 2554]}
# {1472: [8097, 14793]}
# {1473: [2715, 3902]}
# {1474: [6381, 1327]}
# {1475: [6516, 6860]}
# {1476: [15207, 9798]}
# {1477: [13226, 8128]}
# {1478: [11498, 9978]}
# {1479: [14899, 6008]}
# {1480: [3622, 13969]}
# {1481: [8579, 2522]}
# {1482: [13575, 4431]}
# {1483: [6465, 12481]}
# {1484: [14308, 9911]}
# {1485: [4515, 4298]}
# {1486: [3061, 6502]}
# {1487: [14352, 9366]}
# {1488: [5832, 15238]}
# {1489: [3892, 14151]}
# {1490: [9748, 6436]}
# {1491: [10354, 9984]}
# {1492: [5266, 2039]}
# {1493: [1066, 136]}
# {1494: [13855, 13355]}
# {1495: [8657, 5436]}
# {1496: [6679, 4709]}
# {1497: [3995, 546]}
# {1498: [10523, 8488]}
# {1499: [10775, 14303]}
# {1500: [12224, 6359]}
# {1501: [7017, 3]}
# {1502: [735, 7697]}
# {1503: [9132, 9500]}
# {1504: [9196, 8793]}
# {1505: [15164, 7595]}
# {1506: [6098, 13169]}
# {1507: [6131, 11457]}
# {1508: [12690, 2946]}
# {1509: [3660, 5049]}
# {1510: [5564, 5200]}
# {1511: [2431, 7701]}
# {1512: [14215, 15148]}
# {1513: [9567, 13133]}
# {1514: [8571, 43]}
# {1515: [3422, 9153]}
# {1516: [14123, 11526]}
# {1517: [12229, 5705]}
# {1518: [13767, 4224]}
# {1519: [2976, 15099]}
# {1520: [14368, 2024]}
# {1521: [9466, 69]}
# {1522: [13621, 14747]}
# {1523: [4695, 11686]}
# {1524: [10061, 9974]}
# {1525: [3187, 14605]}
# {1526: [11179, 9810]}
# {1527: [5542, 8113]}
# {1528: [1836, 13788]}
# {1529: [3152, 1233]}
# {1530: [416, 9913]}
# {1531: [7176, 8613]}
# {1532: [375, 9667]}
# {1533: [11731, 10296]}
# {1534: [12297, 13971]}
# {1535: [9926, 14064]}
# {1536: [11083, 6490]}
# {1537: [6252, 11130]}
# {1538: [1795, 5631]}
# {1539: [3590, 6151]}
# {1540: [3288, 8144]}
# {1541: [2254, 11078]}
# {1542: [13974, 12646]}
# {1543: [13146, 1676]}
# {1544: [4893, 9873]}
# {1545: [12569, 13006]}
# {1546: [2510, 1585]}
# {1547: [5413, 8723]}
# {1548: [12188, 9731]}
# {1549: [6304, 7194]}
# {1550: [8176, 477]}
# {1551: [7566, 10221]}
# {1552: [3915, 4056]}
# {1553: [10741, 7202]}
# {1554: [1616, 525]}
# {1555: [3541, 2007]}
# {1556: [12467, 5765]}
# {1557: [12695, 12520]}
# {1558: [5004, 6562]}
# {1559: [840, 5800]}
# {1560: [11256, 5074]}
# {1561: [3164, 621]}
# {1562: [1490, 2093]}
# {1563: [6476, 12036]}
# {1564: [2591, 9730]}
# {1565: [13675, 3867]}
# {1566: [3241, 4163]}
# {1567: [11065, 14659]}
# {1568: [11153, 4252]}
# {1569: [2188, 3436]}
# {1570: [14622, 6347]}
# {1571: [2848, 7335]}
# {1572: [1563, 13096]}
# {1573: [261, 11525]}
# {1574: [6083, 2460]}
# {1575: [13041, 11127]}
# {1576: [13208, 10637]}
# {1577: [8294, 8323]}
# {1578: [13415, 12705]}
# {1579: [12236, 5774]}
# {1580: [8381, 11343]}
# {1581: [3776, 12125]}
# {1582: [11312, 3023]}
# {1583: [3846, 11318]}
# {1584: [2109, 7800]}
# {1585: [8068, 1177]}
# {1586: [7583, 4210]}
# {1587: [2160, 2001]}
# {1588: [6247, 3176]}
# {1589: [12714, 13027]}
# {1590: [11349, 10905]}
# {1591: [6774, 1982]}
# {1592: [5954, 14187]}
# {1593: [10079, 6275]}
# {1594: [13587, 4341]}
# {1595: [14561, 15190]}
# {1596: [2990, 10952]}
# {1597: [10953, 9778]}
# {1598: [6344, 2493]}
# {1599: [6216, 11047]}
# {1600: [5759, 12782]}
# {1601: [4222, 11800]}
# {1602: [4512, 13034]}
# {1603: [8876, 14019]}
# {1604: [4118, 7554]}
# {1605: [10211, 1904]}
# {1606: [10454, 6]}
# {1607: [4532, 10375]}
# {1608: [15135, 10540]}
# {1609: [3521, 683]}
# {1610: [1996, 7562]}
# {1611: [5381, 4858]}
# {1612: [9186, 5628]}
# {1613: [14209, 15040]}
# {1614: [5977, 5626]}
# {1615: [341, 12794]}
# {1616: [11340, 8626]}
# {1617: [13584, 2969]}
# {1618: [10758, 11929]}
# {1619: [9246, 8226]}
# {1620: [5713, 714]}
# {1621: [9390, 4337]}
# {1622: [10503, 4442]}
# {1623: [694, 13198]}
# {1624: [13846, 7593]}
# {1625: [1788, 8611]}
# {1626: [12959, 10280]}
# {1627: [11198, 13974]}
# {1628: [8833, 12150]}
# {1629: [12211, 8020]}
# {1630: [4747, 8858]}
# {1631: [9137, 5373]}
# {1632: [10760, 5244]}
# {1633: [14848, 1551]}
# {1634: [4868, 6940]}
# {1635: [6437, 9545]}
# {1636: [9756, 7426]}
# {1637: [12186, 10235]}
# {1638: [7411, 11817]}
# {1639: [11508, 12347]}
# {1640: [4438, 2293]}
# {1641: [3738, 7369]}
# {1642: [1778, 6399]}
# {1643: [1933, 13755]}
# {1644: [11169, 1015]}
# {1645: [11977, 11708]}
# {1646: [12744, 12850]}
# {1647: [14247, 6502]}
# {1648: [7468, 14763]}
# {1649: [5233, 11840]}
# {1650: [280, 1295]}
# {1651: [10322, 9731]}
# {1652: [4339, 6351]}
# {1653: [1851, 3796]}
# {1654: [15171, 11192]}
# {1655: [5187, 7627]}
# {1656: [1724, 10347]}
# {1657: [5126, 12985]}
# {1658: [1969, 11935]}
# {1659: [14910, 1745]}
# {1660: [9211, 12573]}
# {1661: [7807, 3026]}
# {1662: [14182, 4176]}
# {1663: [7457, 12794]}
# {1664: [7461, 5075]}
# {1665: [12609, 2864]}
# {1666: [6280, 1311]}
# {1667: [1423, 9011]}
# {1668: [10009, 10386]}
# {1669: [12617, 2692]}
# {1670: [7143, 8491]}
# {1671: [4643, 5886]}
# {1672: [7510, 1176]}
# {1673: [570, 4757]}
# {1674: [12595, 4109]}
# {1675: [12210, 5251]}
# {1676: [2698, 9018]}
# {1677: [6458, 1561]}
# {1678: [9558, 13680]}
# {1679: [13500, 2418]}
# {1680: [14240, 15264]}
# {1681: [12004, 2460]}
# {1682: [4305, 1555]}
# {1683: [10259, 10741]}
# {1684: [8463, 11444]}
# {1685: [4110, 5977]}
# {1686: [8, 884]}
# {1687: [8509, 5041]}
# {1688: [2945, 11467]}
# {1689: [13597, 14068]}
# {1690: [10139, 11781]}
# {1691: [14273, 8877]}
# {1692: [13660, 10835]}
# {1693: [10151, 755]}
# {1694: [3074, 5332]}
# {1695: [8867, 13701]}
# {1696: [1772, 2492]}
# {1697: [3544, 1382]}
# {1698: [12138, 6834]}
# {1699: [11127, 5172]}
# {1700: [9267, 13432]}
# {1701: [1447, 12965]}
# {1702: [14550, 9795]}
# {1703: [96, 4017]}
# {1704: [15263, 10535]}
# {1705: [2781, 9572]}
# {1706: [1617, 3677]}
# {1707: [2987, 4141]}
# {1708: [8321, 305]}
# {1709: [7274, 7021]}
# {1710: [12851, 8010]}
# {1711: [6301, 8576]}
# {1712: [7983, 1407]}
# {1713: [14728, 4894]}
# {1714: [4710, 1607]}
# {1715: [810, 1506]}
# {1716: [6692, 9543]}
# {1717: [10235, 5295]}
# {1718: [1177, 2214]}
# {1719: [405, 11435]}
# {1720: [5596, 13532]}
# {1721: [982, 91]}
# {1722: [2886, 6547]}
# {1723: [635, 6542]}
# {1724: [3707, 12376]}
# {1725: [15053, 1930]}
# {1726: [4949, 4507]}
# {1727: [10737, 6974]}
# {1728: [14879, 2526]}
# {1729: [5519, 3918]}
# {1730: [9386, 5099]}
# {1731: [10626, 10609]}
# {1732: [12, 10092]}
# {1733: [3234, 15208]}
# {1734: [1986, 14291]}
# {1735: [14024, 6828]}
# {1736: [6186, 8493]}
# {1737: [908, 766]}
# {1738: [6107, 1127]}
# {1739: [4102, 748]}
# {1740: [12603, 7472]}
# {1741: [913, 1962]}
# {1742: [263, 12560]}
# {1743: [8676, 4609]}
# {1744: [12862, 11417]}
# {1745: [3744, 3500]}
# {1746: [8623, 3388]}
# {1747: [4177, 12460]}
# {1748: [494, 7134]}
# {1749: [3225, 5954]}
# {1750: [4832, 13722]}
# {1751: [14954, 14618]}
# {1752: [5333, 9489]}
# {1753: [12691, 9128]}
# {1754: [5328, 10513]}
# {1755: [927, 3950]}
# {1756: [8337, 2875]}
# {1757: [13295, 7856]}
# {1758: [3922, 6971]}
# {1759: [422, 9146]}
# {1760: [8783, 3659]}
# {1761: [15103, 415]}
# {1762: [9772, 10850]}
# {1763: [10159, 6051]}
# {1764: [9242, 2628]}
# {1765: [7043, 4567]}
# {1766: [7900, 7604]}
# {1767: [5499, 9160]}
# {1768: [4366, 4116]}
# {1769: [2346, 4852]}
# {1770: [13215, 1725]}
# {1771: [7658, 8606]}
# {1772: [12013, 2753]}
# {1773: [6420, 4077]}
# {1774: [10356, 785]}
# {1775: [12443, 13693]}
# {1776: [8992, 10442]}
# {1777: [4008, 10629]}
# {1778: [358, 8975]}
# {1779: [4870, 13566]}
# {1780: [4051, 13110]}
# {1781: [4108, 10301]}
# {1782: [6597, 3513]}
# {1783: [42, 12671]}
# {1784: [6962, 2410]}
# {1785: [4336, 573]}
# {1786: [3750, 1210]}
# {1787: [9527, 9891]}
# {1788: [3865, 2895]}
# {1789: [551, 7972]}
# {1790: [10577, 3416]}
# {1791: [15018, 7359]}
# {1792: [2872, 15057]}
# {1793: [13697, 2003]}
# {1794: [11174, 7330]}
# {1795: [14350, 2654]}
# {1796: [15165, 11561]}
# {1797: [1769, 14959]}
# {1798: [11612, 10755]}
# {1799: [11021, 14856]}
# {1800: [5671, 14536]}
# {1801: [3417, 6720]}
# {1802: [9513, 11323]}
# {1803: [2340, 15164]}
# {1804: [13724, 11019]}
# {1805: [10586, 5199]}
# {1806: [9265, 9859]}
# {1807: [14469, 11925]}
# {1808: [2509, 13371]}
# {1809: [1225, 6780]}
# {1810: [5436, 15164]}
# {1811: [14188, 151]}
# {1812: [626, 6902]}
# {1813: [13652, 10739]}
# {1814: [5207, 1147]}
# {1815: [5999, 12097]}
# {1816: [6071, 3436]}
# {1817: [12114, 14317]}
# {1818: [14000, 9345]}
# {1819: [9731, 6291]}
# {1820: [4547, 11733]}
# {1821: [10548, 8819]}
# {1822: [10790, 10849]}
# {1823: [13595, 11942]}
# {1824: [2717, 4608]}
# {1825: [6914, 4154]}
# {1826: [7904, 1087]}
# {1827: [110, 10753]}
# {1828: [2936, 1946]}
# {1829: [14927, 10105]}
# {1830: [13205, 10066]}
# {1831: [6338, 9963]}
# {1832: [7672, 4142]}
# {1833: [9802, 5508]}
# {1834: [10885, 9970]}
# {1835: [8319, 250]}
# {1836: [11845, 13241]}
# {1837: [2134, 52]}
# {1838: [1629, 10799]}
# {1839: [7488, 1975]}
# {1840: [13885, 5391]}
# {1841: [12124, 8593]}
# {1842: [4754, 12868]}
# {1843: [4646, 5542]}
# {1844: [1875, 10769]}
# {1845: [10321, 2930]}
# {1846: [14093, 2680]}
# {1847: [5739, 3254]}
# {1848: [13582, 4200]}
# {1849: [9647, 10293]}
# {1850: [12126, 622]}
# {1851: [11267, 6320]}
# {1852: [8417, 1981]}
# {1853: [12241, 1151]}
# {1854: [2788, 8175]}
# {1855: [7357, 11452]}
# {1856: [3296, 5223]}
# {1857: [9762, 605]}
# {1858: [782, 4121]}
# {1859: [6427, 13125]}
# {1860: [9289, 901]}
# {1861: [12493, 11417]}
# {1862: [9469, 7804]}
# {1863: [10930, 7083]}
# {1864: [12783, 2746]}
# {1865: [10510, 1186]}
# {1866: [9712, 13633]}
# {1867: [5848, 10213]}
# {1868: [4758, 9747]}
# {1869: [3499, 10034]}
# {1870: [10158, 6780]}
# {1871: [3340, 8967]}
# {1872: [6689, 10071]}
# {1873: [9441, 7340]}
# {1874: [6842, 1303]}
# {1875: [481, 14157]}
# {1876: [13235, 5484]}
# {1877: [13861, 5371]}
# {1878: [4096, 11456]}
# {1879: [6494, 5229]}
# {1880: [9613, 7303]}
# {1881: [6108, 8505]}
# {1882: [6248, 2882]}
# {1883: [5601, 14017]}
# {1884: [8173, 12486]}
# {1885: [8718, 396]}
# {1886: [1607, 5936]}
# {1887: [3820, 10680]}
# {1888: [8784, 6412]}
# {1889: [10528, 9161]}
# {1890: [9324, 11761]}
# {1891: [9550, 6975]}
# {1892: [8140, 3298]}
# {1893: [7409, 6394]}
# {1894: [6300, 7434]}
# {1895: [14842, 10608]}
# {1896: [7809, 14975]}
# {1897: [5042, 9259]}
# {1898: [5489, 5702]}
# {1899: [9778, 14552]}
# {1900: [6872, 13618]}
# {1901: [4486, 2803]}
# {1902: [9878, 8166]}
# {1903: [10004, 9111]}
# {1904: [955, 3105]}
# {1905: [3136, 8045]}
# {1906: [8190, 4923]}
# {1907: [8727, 11860]}
# {1908: [6222, 1692]}
# {1909: [648, 11857]}
# {1910: [7646, 6044]}
# {1911: [12938, 10885]}
# {1912: [4999, 6840]}
# {1913: [14888, 11469]}
# {1914: [14937, 6383]}
# {1915: [13239, 311]}
# {1916: [14441, 9702]}
# {1917: [2907, 12982]}
# {1918: [11620, 12204]}
# {1919: [11439, 1506]}
# {1920: [11439, 13807]}
# {1921: [11620, 3109]}
# {1922: [2907, 2331]}
# {1923: [14441, 5611]}
# {1924: [13239, 15002]}
# {1925: [14937, 8930]}
# {1926: [14888, 3844]}
# {1927: [4999, 8473]}
# {1928: [12938, 4428]}
# {1929: [7646, 9269]}
# {1930: [648, 3456]}
# {1931: [6222, 13621]}
# {1932: [8727, 3453]}
# {1933: [8190, 10390]}
# {1934: [3136, 7268]}
# {1935: [955, 12208]}
# {1936: [10004, 6202]}
# {1937: [9878, 7147]}
# {1938: [4486, 12510]}
# {1939: [6872, 1695]}
# {1940: [9778, 761]}
# {1941: [5489, 9611]}
# {1942: [5042, 6054]}
# {1943: [7809, 338]}
# {1944: [14842, 4705]}
# {1945: [6300, 7879]}
# {1946: [7409, 8919]}
# {1947: [8140, 12015]}
# {1948: [9550, 8338]}
# {1949: [9324, 3552]}
# {1950: [10528, 6152]}
# {1951: [8784, 8901]}
# {1952: [3820, 4633]}
# {1953: [1607, 9377]}
# {1954: [8718, 14917]}
# {1955: [8173, 2827]}
# {1956: [5601, 1296]}
# {1957: [6248, 12431]}
# {1958: [6108, 6808]}
# {1959: [9613, 8010]}
# {1960: [6494, 10084]}
# {1961: [4096, 3857]}
# {1962: [13861, 9942]}
# {1963: [13235, 9829]}
# {1964: [481, 1156]}
# {1965: [6842, 14010]}
# {1966: [9441, 7973]}
# {1967: [6689, 5242]}
# {1968: [3340, 6346]}
# {1969: [10158, 8533]}
# {1970: [3499, 5279]}
# {1971: [4758, 5566]}
# {1972: [5848, 5100]}
# {1973: [9712, 1680]}
# {1974: [10510, 14127]}
# {1975: [12783, 12567]}
# {1976: [10930, 8230]}
# {1977: [9469, 7509]}
# {1978: [12493, 3896]}
# {1979: [9289, 14412]}
# {1980: [6427, 2188]}
# {1981: [782, 11192]}
# {1982: [9762, 14708]}
# {1983: [3296, 10090]}
# {1984: [7357, 3861]}
# {1985: [2788, 7138]}
# {1986: [12241, 14162]}
# {1987: [8417, 13332]}
# {1988: [11267, 8993]}
# {1989: [12126, 14691]}
# {1990: [9647, 5020]}
# {1991: [13582, 11113]}
# {1992: [5739, 12059]}
# {1993: [14093, 12633]}
# {1994: [10321, 12383]}
# {1995: [1875, 4544]}
# {1996: [4646, 9771]}
# {1997: [4754, 2445]}
# {1998: [12124, 6720]}
# {1999: [13885, 9922]}
# {2000: [7488, 13338]}
# {2001: [1629, 4514]}
# {2002: [2134, 15261]}
# {2003: [11845, 2072]}
# {2004: [8319, 15063]}
# {2005: [10885, 5343]}
# {2006: [9802, 9805]}
# {2007: [7672, 11171]}
# {2008: [6338, 5350]}
# {2009: [13205, 5247]}
# {2010: [14927, 5208]}
# {2011: [2936, 13367]}
# {2012: [110, 4560]}
# {2013: [7904, 14226]}
# {2014: [6914, 11159]}
# {2015: [2717, 10705]}
# {2016: [13595, 3371]}
# {2017: [10790, 4464]}
# {2018: [10548, 6494]}
# {2019: [4547, 3580]}
# {2020: [9731, 9022]}
# {2021: [14000, 5968]}
# {2022: [12114, 996]}
# {2023: [6071, 11877]}
# {2024: [5999, 3216]}
# {2025: [5207, 14166]}
# {2026: [13652, 4574]}
# {2027: [626, 8411]}
# {2028: [14188, 15162]}
# {2029: [5436, 149]}
# {2030: [1225, 8533]}
# {2031: [2509, 1942]}
# {2032: [14469, 3388]}
# {2033: [9265, 5454]}
# {2034: [10586, 10114]}
# {2035: [13724, 4294]}
# {2036: [2340, 149]}
# {2037: [9513, 3990]}
# {2038: [3417, 8593]}
# {2039: [5671, 777]}
# {2040: [11021, 457]}
# {2041: [11612, 4558]}
# {2042: [1769, 354]}
# {2043: [15165, 3752]}
# {2044: [14350, 12659]}
# {2045: [11174, 7983]}
# {2046: [13697, 13310]}
# {2047: [2872, 256]}
# {2048: [15018, 7954]}
# {2049: [10577, 11897]}
# {2050: [551, 7341]}
# {2051: [3865, 12418]}
# {2052: [9527, 5422]}
# {2053: [3750, 14103]}
# {2054: [4336, 14740]}
# {2055: [6962, 12903]}
# {2056: [42, 2642]}
# {2057: [6597, 11800]}
# {2058: [4108, 5012]}
# {2059: [4051, 2203]}
# {2060: [4870, 1747]}
# {2061: [358, 6338]}
# {2062: [4008, 4684]}
# {2063: [8992, 4871]}
# {2064: [12443, 1620]}
# {2065: [10356, 14528]}
# {2066: [6420, 11236]}
# {2067: [12013, 12560]}
# {2068: [7658, 6707]}
# {2069: [13215, 13588]}
# {2070: [2346, 10461]}
# {2071: [4366, 11197]}
# {2072: [5499, 6153]}
# {2073: [7900, 7709]}
# {2074: [7043, 10746]}
# {2075: [9242, 12685]}
# {2076: [10159, 9262]}
# {2077: [9772, 4463]}
# {2078: [15103, 14898]}
# {2079: [8783, 11654]}
# {2080: [422, 6167]}
# {2081: [3922, 8342]}
# {2082: [13295, 7457]}
# {2083: [8337, 12438]}
# {2084: [927, 11363]}
# {2085: [5328, 4800]}
# {2086: [12691, 6185]}
# {2087: [5333, 5824]}
# {2088: [14954, 695]}
# {2089: [4832, 1591]}
# {2090: [3225, 9359]}
# {2091: [494, 8179]}
# {2092: [4177, 2853]}
# {2093: [8623, 11925]}
# {2094: [3744, 11813]}
# {2095: [12862, 3896]}
# {2096: [8676, 10704]}
# {2097: [263, 2753]}
# {2098: [913, 13351]}
# {2099: [12603, 7841]}
# {2100: [4102, 14565]}
# {2101: [6107, 14186]}
# {2102: [908, 14547]}
# {2103: [6186, 6820]}
# {2104: [14024, 8485]}
# {2105: [1986, 1022]}
# {2106: [3234, 105]}
# {2107: [12, 5221]}
# {2108: [10626, 4704]}
# {2109: [9386, 10214]}
# {2110: [5519, 11395]}
# {2111: [14879, 12787]}
# {2112: [10737, 8339]}
# {2113: [4949, 10806]}
# {2114: [15053, 13383]}
# {2115: [3707, 2937]}
# {2116: [635, 8771]}
# {2117: [2886, 8766]}
# {2118: [982, 15222]}
# {2119: [5596, 1781]}
# {2120: [405, 3878]}
# {2121: [1177, 13099]}
# {2122: [10235, 10018]}
# {2123: [6692, 5770]}
# {2124: [810, 13807]}
# {2125: [4710, 13706]}
# {2126: [14728, 10419]}
# {2127: [7983, 13906]}
# {2128: [6301, 6737]}
# {2129: [12851, 7303]}
# {2130: [7274, 8292]}
# {2131: [8321, 15008]}
# {2132: [2987, 11172]}
# {2133: [1617, 11636]}
# {2134: [2781, 5741]}
# {2135: [15263, 4778]}
# {2136: [96, 11296]}
# {2137: [14550, 5518]}
# {2138: [1447, 2348]}
# {2139: [9267, 1881]}
# {2140: [11127, 10141]}
# {2141: [12138, 8479]}
# {2142: [3544, 13931]}
# {2143: [1772, 12821]}
# {2144: [8867, 1612]}
# {2145: [3074, 9981]}
# {2146: [10151, 14558]}
# {2147: [13660, 4478]}
# {2148: [14273, 6436]}
# {2149: [10139, 3532]}
# {2150: [13597, 1245]}
# {2151: [2945, 3846]}
# {2152: [8509, 10272]}
# {2153: [8, 14429]}
# {2154: [4110, 9336]}
# {2155: [8463, 3869]}
# {2156: [10259, 4572]}
# {2157: [4305, 13758]}
# {2158: [12004, 12853]}
# {2159: [14240, 49]}
# {2160: [13500, 12895]}
# {2161: [9558, 1633]}
# {2162: [6458, 13752]}
# {2163: [2698, 6295]}
# {2164: [12210, 10062]}
# {2165: [12595, 11204]}
# {2166: [570, 10556]}
# {2167: [7510, 14137]}
# {2168: [4643, 9427]}
# {2169: [7143, 6822]}
# {2170: [12617, 12621]}
# {2171: [10009, 4927]}
# {2172: [1423, 6302]}
# {2173: [6280, 14002]}
# {2174: [12609, 12449]}
# {2175: [7461, 10238]}
# {2176: [7457, 2519]}
# {2177: [14182, 11137]}
# {2178: [7807, 12287]}
# {2179: [9211, 2740]}
# {2180: [14910, 13568]}
# {2181: [1969, 3378]}
# {2182: [5126, 2328]}
# {2183: [1724, 4966]}
# {2184: [5187, 7686]}
# {2185: [15171, 4121]}
# {2186: [1851, 11517]}
# {2187: [4339, 8962]}
# {2188: [10322, 5582]}
# {2189: [280, 14018]}
# {2190: [5233, 3473]}
# {2191: [7468, 550]}
# {2192: [14247, 8811]}
# {2193: [12744, 2463]}
# {2194: [11977, 3605]}
# {2195: [11169, 14298]}
# {2196: [1933, 1558]}
# {2197: [1778, 8914]}
# {2198: [3738, 7944]}
# {2199: [4438, 13020]}
# {2200: [11508, 2966]}
# {2201: [7411, 3496]}
# {2202: [12186, 5078]}
# {2203: [9756, 7887]}
# {2204: [6437, 5768]}
# {2205: [4868, 8373]}
# {2206: [14848, 13762]}
# {2207: [10760, 10069]}
# {2208: [9137, 9940]}
# {2209: [4747, 6455]}
# {2210: [12211, 7293]}
# {2211: [8833, 3163]}
# {2212: [11198, 1339]}
# {2213: [12959, 5033]}
# {2214: [1788, 6702]}
# {2215: [13846, 7720]}
# {2216: [694, 2115]}
# {2217: [10503, 10871]}
# {2218: [9390, 10976]}
# {2219: [5713, 14599]}
# {2220: [9246, 7087]}
# {2221: [10758, 3384]}
# {2222: [13584, 12344]}
# {2223: [11340, 6687]}
# {2224: [341, 2519]}
# {2225: [5977, 9687]}
# {2226: [14209, 273]}
# {2227: [9186, 9685]}
# {2228: [5381, 10455]}
# {2229: [1996, 7751]}
# {2230: [3521, 14630]}
# {2231: [15135, 4773]}
# {2232: [4532, 4938]}
# {2233: [10454, 15307]}
# {2234: [10211, 13409]}
# {2235: [4118, 7759]}
# {2236: [8876, 1294]}
# {2237: [4512, 2279]}
# {2238: [4222, 3513]}
# {2239: [5759, 2531]}
# {2240: [6216, 4266]}
# {2241: [6344, 12820]}
# {2242: [10953, 5535]}
# {2243: [2990, 4361]}
# {2244: [14561, 123]}
# {2245: [13587, 10972]}
# {2246: [10079, 9038]}
# {2247: [5954, 1126]}
# {2248: [6774, 13331]}
# {2249: [11349, 4408]}
# {2250: [12714, 2286]}
# {2251: [6247, 12137]}
# {2252: [2160, 13312]}
# {2253: [7583, 11103]}
# {2254: [8068, 14136]}
# {2255: [2109, 7513]}
# {2256: [3846, 3995]}
# {2257: [11312, 12290]}
# {2258: [3776, 3188]}
# {2259: [8381, 3970]}
# {2260: [12236, 9539]}
# {2261: [13415, 2608]}
# {2262: [8294, 6990]}
# {2263: [13208, 4676]}
# {2264: [13041, 4186]}
# {2265: [6083, 12853]}
# {2266: [261, 3788]}
# {2267: [1563, 2217]}
# {2268: [2848, 7978]}
# {2269: [14622, 8966]}
# {2270: [2188, 11877]}
# {2271: [11153, 11061]}
# {2272: [11065, 654]}
# {2273: [3241, 11150]}
# {2274: [13675, 11446]}
# {2275: [2591, 5583]}
# {2276: [6476, 3277]}
# {2277: [1490, 13220]}
# {2278: [3164, 14692]}
# {2279: [11256, 10239]}
# ...
# {3149: [14681, 6712]}
# {3150: [4833, 2467]}
# {3151: [1352, 6200]}
# {3152: [15015, 1049]}
# {3153: [9916, 13113]}
# {3154: [14800, 14441]}
# {3155: [3733, 8079]}
# {3156: [4978, 14363]}
# {3157: [5971, 3846]}
# {3158: [9043, 11274]}
# {3159: [14332, 2108]}
# {3160: [1223, 3210]}
# {3161: [7775, 13424]}
# {3162: [1499, 4481]}
# {3163: [4519, 14290]}
# {3164: [14471, 9451]}
# {3165: [5129, 1423]}
# {3166: [2397, 15012]}
# {3167: [13826, 6139]}
# {3168: [4217, 14639]}
# {3169: [5090, 14745]}
# {3170: [12320, 4995]}
# {3171: [8766, 10513]}
# {3172: [14610, 13711]}
# {3173: [6509, 5958]}
# {3174: [10801, 13243]}
# {3175: [9643, 7590]}
# {3176: [7318, 3942]}
# {3177: [7969, 1314]}
# {3178: [4542, 6193]}
# {3179: [13264, 10630]}
# {3180: [1965, 2049]}
# {3181: [9377, 13402]}
# {3182: [8226, 4302]}
# {3183: [13045, 10403]}
# {3184: [7676, 8045]}
# {3185: [8504, 11307]}
# {3186: [12792, 3916]}
# {3187: [10160, 15255]}
# {3188: [14252, 12125]}
# {3189: [11512, 6996]}
# {3190: [3635, 6272]}
# {3191: [11603, 5121]}
# {3192: [1286, 12379]}
# {3193: [4061, 6290]}
# {3194: [2831, 7754]}
# {3195: [4716, 14041]}
# {3196: [6596, 14570]}
# {3197: [3716, 10424]}
# {3198: [14715, 12207]}
# {3199: [8116, 5582]}
# {3200: [5001, 10066]}
# {3201: [7026, 14215]}
# {3202: [13359, 4644]}
# {3203: [13077, 4908]}
# {3204: [10141, 8400]}
# {3205: [13663, 8842]}
# {3206: [8916, 13082]}
# {3207: [10180, 14700]}
# {3208: [7341, 7724]}
# {3209: [3387, 2012]}
# {3210: [13958, 15305]}
# {3211: [6734, 808]}
# {3212: [2757, 8360]}
# {3213: [9551, 5635]}
# {3214: [5433, 259]}
# {3215: [1324, 11458]}
# {3216: [11610, 6364]}
# {3217: [8435, 10288]}
# {3218: [2375, 1635]}
# {3219: [14166, 14600]}
# {3220: [12718, 9752]}
# {3221: [8819, 6194]}
# {3222: [12562, 2057]}
# {3223: [1124, 14697]}
# {3224: [8403, 13894]}
# {3225: [10363, 541]}
# {3226: [5877, 4333]}
# {3227: [10869, 3914]}
# {3228: [7367, 3828]}
# {3229: [6128, 11694]}
# {3230: [12371, 8306]}
# {3231: [5953, 7263]}
# {3232: [165, 4464]}
# {3233: [14059, 9372]}
# {3234: [4841, 8086]}
# {3235: [14850, 2638]}
# {3236: [12928, 5774]}
# {3237: [12849, 3580]}
# {3238: [9758, 3801]}
# {3239: [2221, 5987]}
# {3240: [11478, 13771]}
# {3241: [2774, 12943]}
# {3242: [9744, 9339]}
# {3243: [10117, 4840]}
# {3244: [1731, 8664]}
# {3245: [1919, 9837]}
# {3246: [12150, 1046]}
# {3247: [1826, 6924]}
# {3248: [3455, 11214]}
# {3249: [6554, 12461]}
# {3250: [14409, 10047]}
# {3251: [175, 7224]}
# {3252: [14199, 3129]}
# {3253: [8242, 2660]}
# {3254: [14445, 12810]}
# {3255: [12539, 12853]}
# {3256: [7761, 11930]}
# {3257: [15045, 9815]}
# {3258: [5341, 9889]}
# {3259: [11525, 11393]}
# {3260: [9047, 5853]}
# {3261: [1121, 4902]}
# {3262: [4429, 1303]}
# {3263: [11622, 6656]}
# {3264: [4690, 7956]}
# {3265: [14235, 8687]}
# {3266: [15304, 11824]}
# {3267: [1262, 9737]}
# {3268: [10777, 14346]}
# {3269: [3864, 3579]}
# {3270: [414, 14317]}
# {3271: [2776, 7846]}
# {3272: [2424, 1607]}
# {3273: [8616, 9961]}
# {3274: [5702, 642]}
# {3275: [3676, 142]}
# {3276: [9291, 11915]}
# {3277: [11586, 5946]}
# {3278: [7515, 2519]}
# {3279: [7994, 1656]}
# {3280: [12397, 5597]}
# {3281: [4641, 13267]}
# {3282: [9605, 11359]}
# {3283: [10441, 2361]}
# {3284: [1947, 6036]}
# {3285: [14143, 4483]}
# {3286: [9468, 13238]}
# {3287: [495, 231]}
# {3288: [10387, 1424]}
# {3289: [15078, 6402]}
# {3290: [7857, 14247]}
# {3291: [6868, 8876]}
# {3292: [12494, 1863]}
# {3293: [3010, 1666]}
# {3294: [6985, 1382]}
# {3295: [12148, 12639]}
# {3296: [7958, 9507]}
# {3297: [11986, 417]}
# {3298: [12430, 8432]}
# {3299: [12765, 3483]}
# {3300: [606, 11055]}
# {3301: [3002, 6260]}
# {3302: [8651, 14505]}
# {3303: [1567, 14211]}
# {3304: [1753, 8612]}
# {3305: [6026, 10707]}
# {3306: [4048, 13261]}
# {3307: [8024, 10568]}
# {3308: [9065, 6510]}
# {3309: [10266, 3558]}
# {3310: [4633, 9771]}
# {3311: [1803, 3927]}
# {3312: [1715, 15255]}
# {3313: [10071, 11826]}
# {3314: [13808, 4707]}
# {3315: [3133, 2889]}
# {3316: [13721, 14268]}
# {3317: [10474, 13206]}
# {3318: [28, 11732]}
# {3319: [616, 9977]}
# {3320: [9281, 12818]}
# {3321: [10564, 11634]}
# {3322: [3319, 4607]}
# {3323: [13934, 15025]}
# {3324: [4247, 5248]}
# {3325: [1906, 9605]}
# {3326: [5535, 3307]}
# {3327: [2314, 4467]}
# {3328: [5067, 5890]}
# {3329: [10027, 2113]}
# {3330: [4558, 4268]}
# {3331: [11048, 195]}
# {3332: [10716, 3243]}
# {3333: [11463, 7508]}
# {3334: [2034, 7125]}
# {3335: [1107, 4323]}
# {3336: [3236, 4372]}
# {3337: [14973, 10318]}
# {3338: [11696, 12729]}
# {3339: [8252, 8906]}
# {3340: [6743, 11743]}
# {3341: [8290, 14784]}
# {3342: [12422, 3850]}
# {3343: [9784, 13210]}
# {3344: [11320, 478]}
# {3345: [14664, 534]}
# {3346: [10043, 6873]}
# {3347: [12317, 14612]}
# {3348: [10532, 9286]}
# {3349: [9342, 2231]}
# {3350: [13324, 2686]}
# {3351: [13686, 2462]}
# {3352: [3179, 2848]}
# {3353: [8612, 9447]}
# {3354: [554, 6377]}
# {3355: [3631, 6522]}
# {3356: [15296, 5270]}
# {3357: [14718, 5327]}
# {3358: [13470, 10782]}
# {3359: [6942, 13836]}
# {3360: [1714, 977]}
# {3361: [10445, 6029]}
# {3362: [8844, 14796]}
# {3363: [4968, 14953]}
# {3364: [9817, 930]}
# {3365: [2469, 2543]}
# {3366: [6464, 9636]}
# {3367: [13204, 12486]}
# {3368: [346, 3810]}
# {3369: [7292, 9948]}
# {3370: [8531, 15013]}
# {3371: [5783, 334]}
# {3372: [3419, 3132]}
# {3373: [13706, 3820]}
# {3374: [15297, 10261]}
# {3375: [11197, 2610]}
# {3376: [2880, 6562]}
# {3377: [5189, 12257]}
# {3378: [171, 6002]}
# {3379: [12506, 14751]}
# {3380: [7065, 14150]}
# {3381: [10721, 10675]}
# {3382: [7183, 2055]}
# {3383: [6846, 12340]}
# {3384: [13833, 1790]}
# {3385: [7054, 11877]}
# {3386: [14869, 6339]}
# {3387: [7479, 6159]}
# {3388: [4871, 7118]}
# {3389: [10922, 11823]}
# {3390: [13177, 13042]}
# {3391: [13424, 3458]}
# {3392: [10271, 3095]}
# {3393: [8809, 3316]}
# {3394: [7320, 7909]}
# {3395: [14493, 7769]}
# {3396: [3989, 8543]}
# {3397: [13954, 1495]}
# {3398: [10955, 11622]}
# {3399: [10319, 8364]}
# {3400: [2817, 11408]}
# {3401: [14829, 605]}
# {3402: [6501, 2542]}
# {3403: [5994, 1369]}
# {3404: [14126, 1851]}
# {3405: [13344, 10348]}
# {3406: [3008, 1325]}
# {3407: [1358, 12258]}
# {3408: [1901, 6421]}
# {3409: [413, 4400]}
# {3410: [10418, 6690]}
# {3411: [8658, 5222]}
# {3412: [1103, 3873]}
# {3413: [2123, 6636]}
# {3414: [62, 14006]}
# {3415: [11213, 8527]}
# {3416: [11266, 10143]}
# {3417: [13960, 3032]}
# {3418: [886, 14589]}
# {3419: [12956, 8174]}
# {3420: [1361, 652]}
# {3421: [2796, 4821]}
# {3422: [1048, 6084]}
# {3423: [3142, 820]}
# {3424: [14894, 4624]}
# {3425: [9873, 14450]}
# {3426: [6769, 292]}
# {3427: [2316, 5470]}
# {3428: [6429, 5785]}
# {3429: [6043, 5587]}
# {3430: [5624, 14821]}
# {3431: [8690, 8153]}
# {3432: [13919, 9840]}
# {3433: [9876, 7124]}
# {3434: [5575, 560]}
# {3435: [9478, 4012]}
# {3436: [11526, 1540]}
# {3437: [10368, 4362]}
# {3438: [10900, 1846]}
# {3439: [11588, 13697]}
# {3440: [9260, 6422]}
# {3441: [11453, 10171]}
# {3442: [12215, 6786]}
# {3443: [6309, 8419]}
# {3444: [8794, 14075]}
# {3445: [5034, 10666]}
# {3446: [12867, 10886]}
# {3447: [2302, 1767]}
# {3448: [3056, 6544]}
# {3449: [10412, 12989]}
# {3450: [244, 12547]}
# {3451: [9170, 11487]}
# {3452: [12166, 11116]}
# {3453: [12017, 5624]}
# {3454: [7827, 4231]}
# {3455: [8300, 487]}
# {3456: [4483, 15089]}
# {3457: [10195, 4002]}
# {3458: [4074, 9903]}
# {3459: [9016, 744]}
# {3460: [994, 8682]}
# {3461: [15190, 9616]}
# {3462: [11265, 6881]}
# {3463: [11983, 9660]}
# {3464: [6989, 6922]}
# {3465: [10960, 5137]}
# {3466: [10874, 9189]}
# {3467: [7787, 13410]}
# {3468: [9104, 4153]}
# {3469: [2704, 14783]}
# {3470: [12689, 7273]}
# {3471: [13778, 4330]}
# {3472: [3029, 8404]}
# {3473: [7771, 5721]}
# {3474: [12602, 13937]}
# {3475: [3408, 53]}
# {3476: [8395, 8021]}
# {3477: [12069, 274]}
# {3478: [5169, 12099]}
# {3479: [6906, 10526]}
# {3480: [702, 3038]}
# {3481: [4653, 14601]}
# {3482: [5906, 528]}
# {3483: [9593, 5750]}
# {3484: [667, 14936]}
# {3485: [3157, 4163]}
# {3486: [2460, 3921]}
# {3487: [26, 13666]}
# {3488: [14940, 10525]}
# {3489: [6929, 4723]}
# {3490: [6841, 4864]}
# {3491: [6109, 13537]}
# {3492: [5590, 1234]}
# {3493: [6572, 7182]}
# {3494: [8109, 7137]}
# {3495: [9097, 8332]}
# {3496: [3011, 6382]}
# {3497: [6011, 2382]}
# {3498: [6265, 6277]}
# {3499: [1082, 2118]}
# {3500: [10748, 12198]}
# {3501: [6623, 1496]}
# {3502: [14978, 8825]}
# {3503: [4199, 10597]}
# {3504: [12437, 6923]}
# {3505: [3458, 4398]}
# {3506: [14744, 9884]}
# {3507: [8892, 11460]}
# {3508: [4965, 11559]}
# {3509: [4231, 159]}
# {3510: [2813, 3332]}
# {3511: [4260, 4686]}
# {3512: [241, 3522]}
# {3513: [6840, 11258]}
# {3514: [2158, 10323]}
# {3515: [4665, 7950]}
# {3516: [11090, 8560]}
# {3517: [7756, 1318]}
# {3518: [1555, 10059]}
# {3519: [13858, 13034]}
# {3520: [9923, 13480]}
# {3521: [14696, 1014]}
# {3522: [8522, 6801]}
# {3523: [13347, 6569]}
# {3524: [10154, 8228]}
# {3525: [1182, 3076]}
# {3526: [11451, 11816]}
# {3527: [14064, 10349]}
# {3528: [9374, 4466]}
# {3529: [13857, 8015]}
# {3530: [3160, 13685]}
# {3531: [13970, 4817]}
# {3532: [12961, 3695]}
# {3533: [7729, 1112]}
# {3534: [15160, 8187]}
# {3535: [339, 12244]}
# {3536: [3780, 4189]}
# {3537: [12712, 1563]}
# {3538: [12000, 3062]}
# {3539: [6759, 11887]}
# {3540: [1194, 14965]}
# {3541: [12005, 14928]}
# {3542: [86, 5468]}
# {3543: [10914, 12609]}
# {3544: [8282, 14369]}
# {3545: [12234, 4886]}
# {3546: [3529, 5013]}
# {3547: [13128, 7696]}
# {3548: [7214, 5303]}
# {3549: [1492, 12810]}
# {3550: [949, 13973]}
# {3551: [10713, 7758]}
# {3552: [12113, 10236]}
# {3553: [5705, 10785]}
# {3554: [9222, 22]}
# {3555: [14707, 9871]}
# {3556: [11419, 5103]}
# {3557: [11229, 10403]}
# {3558: [14607, 2085]}
# {3559: [11134, 14582]}
# {3560: [10976, 12681]}
# {3561: [11416, 3285]}
# {3562: [6998, 5222]}
# {3563: [13622, 6491]}
# {3564: [3472, 7029]}
# {3565: [10249, 13884]}
# {3566: [6988, 5388]}
# {3567: [8267, 2612]}
# {3568: [6314, 8081]}
# {3569: [5506, 5886]}
# {3570: [8633, 9075]}
# {3571: [14386, 6641]}
# {3572: [12436, 7283]}
# {3573: [1173, 9973]}
# {3574: [13210, 14642]}
# {3575: [7049, 15045]}
# {3576: [13748, 14515]}
# {3577: [15239, 10020]}
# {3578: [1922, 11330]}
# {3579: [14223, 13285]}
# {3580: [7615, 5191]}
# {3581: [5232, 14791]}
# {3582: [1319, 5593]}
# {3583: [6190, 13282]}
# {3584: [2213, 1402]}
# {3585: [4584, 12582]}
# {3586: [10292, 758]}
# {3587: [12480, 9563]}
# {3588: [2282, 10573]}
# {3589: [10798, 8548]}
# {3590: [6362, 2955]}
# {3591: [4186, 2720]}
# {3592: [11515, 5771]}
# {3593: [14088, 3696]}
# {3594: [6961, 9242]}
# {3595: [6553, 910]}
# {3596: [12883, 10266]}
# {3597: [13171, 1229]}
# {3598: [3312, 3227]}
# {3599: [13149, 5539]}
# {3600: [5178, 176]}
# {3601: [14884, 13777]}
# {3602: [8879, 10642]}
# {3603: [13525, 13631]}
# {3604: [14412, 7867]}
# {3605: [5271, 3896]}
# {3606: [9454, 3233]}
# {3607: [564, 14966]}
# {3608: [665, 6331]}
# {3609: [6160, 4181]}
# {3610: [9532, 5491]}
# {3611: [1551, 2017]}
# {3612: [9393, 3753]}
# {3613: [7537, 149]}
# {3614: [14684, 9504]}
# {3615: [11883, 1964]}
# {3616: [3384, 2393]}
# {3617: [10449, 5120]}
# {3618: [7241, 2763]}
# {3619: [267, 10924]}
# {3620: [11272, 9847]}
# {3621: [11001, 6306]}
# {3622: [10342, 426]}
# {3623: [12522, 8651]}
# {3624: [10298, 6200]}
# {3625: [6029, 9200]}
# {3626: [12374, 4748]}
# {3627: [11040, 14054]}
# {3628: [8389, 9989]}
# {3629: [121, 10935]}
# {3630: [11047, 8052]}
# {3631: [10030, 2562]}
# {3632: [7215, 3050]}
# {3633: [5795, 13010]}
# {3634: [3064, 13807]}
# {3635: [14673, 4121]}
# {3636: [5606, 4010]}
# {3637: [3859, 12717]}
# {3638: [6605, 8877]}
# {3639: [12478, 5224]}
# {3640: [629, 4798]}
# {3641: [6499, 14546]}
# {3642: [1404, 13064]}
# {3643: [1215, 7712]}
# {3644: [5310, 9772]}
# {3645: [14420, 1248]}
# {3646: [11287, 5381]}
# {3647: [6407, 12094]}
# {3648: [12133, 7530]}
# {3649: [9752, 14487]}
# {3650: [7209, 12101]}
# {3651: [14295, 13778]}
# {3652: [2138, 14575]}
# {3653: [6683, 7407]}
# {3654: [14743, 376]}
# {3655: [4875, 9239]}
# {3656: [13818, 4434]}
# {3657: [1642, 813]}
# {3658: [4494, 3513]}
# {3659: [103, 6184]}
# {3660: [14540, 14660]}
# {3661: [8940, 12478]}
# {3662: [6165, 4991]}
# {3663: [5281, 14524]}
# {3664: [11072, 10510]}
# {3665: [12424, 316]}
# {3666: [4957, 5358]}
# {3667: [13932, 877]}
# {3668: [6877, 2116]}
# {3669: [8162, 7303]}
# {3670: [3344, 4447]}
# {3671: [9178, 5918]}
# {3672: [3333, 10318]}
# {3673: [3857, 1815]}
# {3674: [5537, 4755]}
# {3675: [6931, 6881]}
# {3676: [10421, 3198]}
# {3677: [8899, 10952]}
# {3678: [11123, 2706]}
# {3679: [3930, 8533]}
# {3680: [11630, 5919]}
# {3681: [11137, 6621]}
# {3682: [11891, 4645]}
# {3683: [8793, 5193]}
# {3684: [6915, 14196]}
# {3685: [10089, 5514]}
# {3686: [7869, 1009]}
# {3687: [12995, 6847]}
# {3688: [1909, 9086]}
# {3689: [6878, 3790]}
# {3690: [1270, 9737]}
# {3691: [7177, 5939]}
# {3692: [13110, 5034]}
# {3693: [3583, 11119]}
# {3694: [5839, 10586]}
# {3695: [3389, 8584]}
# {3696: [12368, 2231]}
# {3697: [6590, 2026]}
# {3698: [8593, 6188]}
# {3699: [8439, 13514]}
# {3700: [9761, 4222]}
# {3701: [2389, 12959]}
# {3702: [1785, 11480]}
# {3703: [1380, 15121]}
# {3704: [451, 2091]}
# {3705: [1374, 12420]}
# {3706: [4578, 8618]}
# {3707: [662, 13167]}
# {3708: [9881, 13900]}
# {3709: [3986, 11611]}
# {3710: [1114, 10553]}
# {3711: [4788, 5260]}
# {3712: [10599, 10696]}
# {3713: [13271, 14718]}
# {3714: [5147, 544]}
# {3715: [10283, 8855]}
# {3716: [9335, 9271]}
# {3717: [12664, 3283]}
# {3718: [8799, 9280]}
# {3719: [1115, 13550]}
# {3720: [10992, 3953]}
# {3721: [12468, 11300]}
# {3722: [15138, 12907]}
# {3723: [2062, 14399]}
# {3724: [8007, 2090]}
# {3725: [9766, 455]}
# {3726: [6289, 2406]}
# {3727: [1870, 14494]}
# {3728: [7908, 7711]}
# {3729: [6277, 9534]}
# {3730: [2799, 1137]}
# {3731: [600, 11532]}
# {3732: [14807, 14909]}
# {3733: [14008, 1587]}
# {3734: [14443, 4151]}
# {3735: [8553, 9563]}
# {3736: [1457, 10904]}
# {3737: [15301, 9137]}
# {3738: [7531, 2249]}
# {3739: [8291, 8007]}
# {3740: [15260, 15247]}
# {3741: [13391, 10291]}
# {3742: [4531, 7556]}
# {3743: [6378, 2249]}
# {3744: [2516, 1252]}
# {3745: [6531, 11729]}
# {3746: [20, 14893]}
# {3747: [5223, 12792]}
# {3748: [15241, 14505]}
# {3749: [9152, 10221]}
# {3750: [9537, 9651]}
# {3751: [3138, 5543]}
# {3752: [4513, 12085]}
# {3753: [2474, 11727]}
# {3754: [10740, 10908]}
# {3755: [7465, 8732]}
# {3756: [8565, 2478]}
# {3757: [2429, 12702]}
# {3758: [2150, 13464]}
# {3759: [3908, 1572]}
# {3760: [15139, 2129]}
# {3761: [10587, 12927]}
# {3762: [429, 6729]}
# {3763: [7982, 1792]}
# {3764: [571, 11004]}
# {3765: [11242, 12394]}
# {3766: [7165, 13313]}
# {3767: [9162, 4279]}
# {3768: [11840, 10142]}
# {3769: [5767, 5929]}
# {3770: [13190, 14917]}
# {3771: [6162, 14067]}
# {3772: [11495, 6729]}
# {3773: [4840, 7387]}
# {3774: [13151, 4406]}
# {3775: [3381, 3799]}
# {3776: [12512, 1223]}
# {3777: [1767, 1795]}
# {3778: [7534, 11925]}
# {3779: [10647, 355]}
# {3780: [11989, 12093]}
# {3781: [13552, 13271]}
# {3782: [6798, 10821]}
# {3783: [14178, 3350]}
# {3784: [7104, 1685]}
# {3785: [7200, 3530]}
# {3786: [3439, 8705]}
# {3787: [13585, 5418]}
# {3788: [13975, 6857]}
# {3789: [1369, 5269]}
# {3790: [10465, 5534]}
# {3791: [14230, 14149]}
# {3792: [5518, 14345]}
# {3793: [10833, 11009]}
# {3794: [3310, 2618]}
# {3795: [11264, 13018]}
# {3796: [1012, 3089]}
# {3797: [10224, 2547]}
# {3798: [11524, 9226]}
# {3799: [15085, 8593]}
# {3800: [11847, 4967]}
# {3801: [513, 10899]}
# {3802: [2230, 10657]}
# {3803: [3129, 8478]}
# {3804: [2008, 10614]}
# {3805: [6972, 13629]}
# {3806: [6932, 14476]}
# {3807: [13726, 9272]}
# {3808: [6218, 12328]}
# {3809: [3037, 2753]}
# {3810: [13709, 12451]}
# {3811: [6205, 5431]}
# {3812: [7198, 6786]}
# {3813: [11502, 9267]}
# {3814: [8331, 5700]}
# {3815: [2710, 1823]}
# {3816: [12967, 614]}
# {3817: [4349, 3351]}
# {3818: [14693, 5798]}
# {3819: [1573, 5627]}
# {3820: [4734, 734]}
# {3821: [1618, 14274]}
# {3822: [13737, 2776]}
# {3823: [7928, 13828]}
# {3824: [1664, 4412]}
# {3825: [1167, 11233]}
# {3826: [11049, 4255]}
# {3827: [9049, 6237]}
# {3828: [14858, 6675]}
# {3829: [12283, 1809]}
# {3830: [7786, 2850]}
# {3831: [2241, 13712]}
# {3832: [13904, 5723]}
# {3833: [948, 4939]}
# {3834: [464, 14390]}
# {3835: [9199, 2406]}
# {3836: [12740, 10309]}
# {3837: [867, 4402]}
# {3838: [10578, 6148]}
# ------------------------------------------------------------------
# TypeError                        Traceback (most recent call last)
# <ipython-input-36-a040f62f1a4b> in <module>
#       1 fl=open("DNA/nodelist.txt","w")
# ----> 2 print(por(p,a,1,1,0,0,fl,q))
#       3 fl.close()
#
# <ipython-input-35-33be0e091ac7> in por(p, a, say, sayf, show, write, fl, mod, retno)
#      52             fl.write(str({i:ret[-1]})+"\n")
#      53             fl.flush()
# ---> 54         ret.append(add(ret[-1],p[0],a,show,write,fl,mod))
#      55         if(retno and ret[-1][0]==p[0][0] and ret[-1][1]==p[0][1]): return {i:ret[-1]}
#      56         i+=1
#
# <ipython-input-35-33be0e091ac7> in add(p, q, a, show, write, fl, mod)
#      19 #        if(write): fl.write("(3*"+str(p[0])+"**2+"+str(a)+")/(2*"+str(p[1])+")")
#      20     #print(3)
# ---> 21     xs=((int(l**2)-p[0]-q[0])%mod+mod)%mod
#      22     so=s+"**2-("+str(p[0])+")-("+str(q[0])+")" + " =\n " + s2+"**2-("+str(p[0])+")-("+str(q[0])+")" + " =\n "+str(xs)
#      23     if(show): print(so)
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'int'

# %%
print(mult([10578,9165],a,127,0,0,0,q))
# Out:
# [4788, 10053]

# %%
print(mult([10578,9165],a,363,0,0,0,q))
# Out:
# [3408, 15260]

# %%
print(mult([3408,15260],a,127,0,0,0,q))
# Out:
# [3133, 12424]

# %%
print((3133*1548)%q)
print((12424*465)%q)
#print(q)

# %%
print(rev(3133,q,q,0,0))
print(rev(12424,q,q,0,0))

# %%
print((7439*10976)%q)
print((1182*4159)%q)

# %%
print(mult([4788,10053],a,363,0,0,0,q))
# Out:
# [3133, 12424]

# %%
print(mult(p[0],a,317,0,0,0,q))
# Out:
# [14696, 14299]

# %%
#(1012;12224) + [317]*(8179;13706)
print(add([1012,12224],mult([8179,13706],a,317,0,0,0,q),a,0,0,0,q))

# %%
#(7465; 6581) - [1147]*(14696;14299) = 
pr=mult([8522,8512],a,1147-1,0,0,0,q)
print(pr)
pr[1]=(q-pr[1])%q
print(pr)

print(add([3233,7560],pr,a,0,0,0,q))
# Out:
# [12472, 8025]
# [12472, 7288]
# [1012, 12224]

# %%
p=[[7406,17549]]
a=-2
b=-1
q=18181
n=15
k=5
pm=[5694,11657]
print(pm)
pa=mult(p[0],a,1764-1,0,0,0,q)
print(pa)
b1=mult(p[0],a,2472-1,0,0,0,q)
print(b1)
b2=add(pm,mult(pa,a,2472-1,0,0,0,q),a,0,0,0,q)
print(b2)
pr=mult(b1,a,1764-1,0,0,0,q)
print(pr)
pr[1]=(q-pr[1])%q
print(pr)

print(add(b2,pr,a,0,0,0,q))

# %%
fl=open("KDS/task2_KDS.txt","w")
p=[[14009,18341]]
a=5
b=-2
q=23981
n=12
k=3


solver(fl,p,a,b,q,n,k)

#pm=[5694,11657]
pm=mult(p[0],a,456-1,0,0,0,q)
print(pm)
pa=mult(p[0],a,764-1,0,0,0,q)
print(pa)
b1=mult(p[0],a,472-1,0,0,0,q)
print(b1)
b2=add(pm,mult(pa,a,472-1,0,0,0,q),a,0,0,0,q)
print(b2)
pr=mult(b1,a,764-1,0,0,0,q)
print(pr)
pr[1]=(q-pr[1])%q
print(pr)

print(add(b2,pr,a,0,0,0,q))


fl.close()

print(por(p,a,1,0,0,0,fl,q))
# Out:
# Проверка кривой на сингулярность:
# 4*(5)**3 - 27*(-2)**2 = 392Кривая не сингулярна и подходит для шифрования
# Point 1 :
# (14009;18341)
#
# Point 2 :
# ((3*(14009)**2+(5))/(2*(18341)))**2-(14009)-(14009) =
#  ((3*(14009)**2+(5))*(7358))**2-(14009)-(14009) =
#  17220
# -(18341)+((3*(14009)**2+(5))/(2*(18341)))*((14009)-(17220)) =
#  -(18341)+((3*(14009)**2+(5))*(7358))*((14009)-(17220)) =
#  6578
# (17220;6578)
#
# Point 3 :
# (((18341)-(6578))/((14009)-(17220)))**2-(17220)-(14009) =
#  (((18341)-(6578))*(21382))**2-(17220)-(14009) =
#  8454
# -(6578)+(((18341)-(6578))/((14009)-(17220)))*((17220)-(8454)) =
#  -(6578)+(((18341)-(6578))*(21382))*((17220)-(8454)) =
#  2684
# (8454;2684)
#
# Point 4 :
# (((18341)-(2684))/((14009)-(8454)))**2-(8454)-(14009) =
#  (((18341)-(2684))*(15429))**2-(8454)-(14009) =
#  7210
# -(2684)+(((18341)-(2684))/((14009)-(8454)))*((8454)-(7210)) =
#  -(2684)+(((18341)-(2684))*(15429))*((8454)-(7210)) =
#  22934
# (7210;22934)
#
# Point 5 :
# (11040;13796)
#
# Point 6 :
# (5748;23722)
#
# Point 7 :
# (16756;11087)
#
# Point 8 :
# (16046;9762)
#
# Point 9 :
# (2117;6202)
#
# Point 10 :
# (14212;1442)
#
# Point 11 :
# (5375;5967)
#
# Point 12 :
# (11818;18718)
# [14904, 4924]
# [1528, 12]
# [12181, 15668]
# [22066, 23775]
# [22623, 19052]
# [22623, 4929]
# [14904, 4924]
# {1: [11818, 18718]}
# {2: [15687, 10471]}
# {3: [22729, 12124]}
# {4: [10172, 23830]}
# {5: [3871, 4362]}
# {6: [7724, 15690]}
# {7: [19828, 2266]}
# {8: [18826, 3913]}
# {9: [12654, 22212]}
# {10: [23389, 18367]}
# {11: [9383, 16861]}
# {12: [20883, 11196]}
# {13: [16904, 11918]}
# {14: [23837, 7614]}
# {15: [21017, 22981]}
# {16: [15892, 15672]}
# {17: [19356, 21306]}
# {18: [19157, 655]}
# {19: [7487, 9786]}
# {20: [2539, 8625]}
# {21: [10446, 3080]}
# {22: [6733, 14634]}
# {23: [21934, 13227]}
# {24: [17699, 6024]}
# {25: [11009, 8689]}
# {26: [16131, 14992]}
# {27: [10007, 21994]}
# {28: [15124, 17306]}
# {29: [9896, 9995]}
# {30: [21935, 22406]}
# {31: [7904, 7582]}
# {32: [8602, 15491]}
# {33: [12112, 1912]}
# {34: [3058, 21990]}
# {35: [6630, 3490]}
# {36: [23481, 6440]}
# {37: [17438, 4305]}
# {38: [9479, 14624]}
# {39: [468, 22484]}
# {40: [16564, 12034]}
# {41: [2361, 20447]}
# {42: [18798, 20584]}
# {43: [6418, 2295]}
# {44: [7293, 23084]}
# {45: [15424, 23461]}
# {46: [3373, 18534]}
# {47: [4187, 7730]}
# {48: [3466, 879]}
# {49: [9445, 13297]}
# {50: [16152, 9724]}
# {51: [18435, 9863]}
# {52: [13910, 18790]}
# {53: [19354, 5416]}
# {54: [22730, 19909]}
# {55: [15326, 21968]}
# {56: [21043, 11779]}
# {57: [20378, 1306]}
# {58: [474, 9994]}
# {59: [6237, 16822]}
# {60: [2464, 3518]}
# {61: [22092, 23873]}
# {62: [3553, 4213]}
# {63: [14807, 9002]}
# {64: [12881, 14076]}
# {65: [9444, 13865]}
# {66: [9663, 17592]}
# {67: [3661, 2689]}
# {68: [8741, 10716]}
# {69: [2480, 545]}
# {70: [3906, 22408]}
# {71: [10853, 7301]}
# {72: [8306, 22763]}
# {73: [16864, 12824]}
# {74: [14417, 6882]}
# {75: [537, 1560]}
# {76: [20469, 9833]}
# {77: [23542, 6227]}
# {78: [10008, 9881]}
# {79: [13104, 20596]}
# {80: [13768, 12989]}
# {81: [14285, 3690]}
# {82: [1669, 14066]}
# {83: [15420, 8348]}
# {84: [5971, 1417]}
# {85: [18647, 21604]}
# {86: [4827, 20714]}
# {87: [303, 22694]}
# {88: [18284, 12231]}
# {89: [21322, 5546]}
# {90: [16186, 313]}
# {91: [5905, 10616]}
# {92: [21466, 8004]}
# {93: [9911, 22789]}
# {94: [6817, 12007]}
# {95: [12868, 20576]}
# {96: [17187, 17750]}
# {97: [3376, 22203]}
# {98: [20749, 15260]}
# {99: [3331, 7085]}
# {100: [11566, 2147]}
# {101: [12544, 14929]}
# {102: [5972, 21510]}
# {103: [23355, 681]}
# {104: [3913, 6074]}
# {105: [12705, 3975]}
# {106: [1290, 21261]}
# {107: [9640, 1032]}
# {108: [10485, 14063]}
# {109: [14141, 11196]}
# {110: [4964, 16921]}
# {111: [16283, 17532]}
# {112: [17381, 17533]}
# {113: [15180, 8936]}
# {114: [11871, 14354]}
# {115: [18835, 1284]}
# {116: [12977, 6097]}
# {117: [11820, 5864]}
# {118: [981, 18187]}
# {119: [14606, 10128]}
# {120: [19218, 18694]}
# {121: [20867, 15879]}
# {122: [566, 8451]}
# {123: [2549, 7146]}
# {124: [10251, 14982]}
# {125: [15963, 19834]}
# {126: [22490, 3934]}
# {127: [5927, 15544]}
# {128: [7967, 9903]}
# {129: [11390, 12322]}
# {130: [23962, 5053]}
# {131: [5888, 101]}
# {132: [12938, 12785]}
# {133: [22258, 10473]}
# {134: [9772, 13204]}
# {135: [821, 17158]}
# {136: [19190, 23161]}
# {137: [23608, 9147]}
# {138: [17358, 14951]}
# {139: [16102, 16824]}
# {140: [16374, 6174]}
# {141: [18903, 5843]}
# {142: [23325, 15338]}
# {143: [4450, 16400]}
# {144: [20216, 4914]}
# {145: [699, 4418]}
# {146: [3938, 20944]}
# {147: [9296, 7265]}
# {148: [22520, 2567]}
# {149: [10169, 9943]}
# {150: [23237, 5093]}
# {151: [9239, 14322]}
# {152: [13906, 4485]}
# {153: [18487, 16502]}
# {154: [2158, 4570]}
# {155: [17978, 12204]}
# {156: [161, 15423]}
# {157: [11201, 3738]}
# {158: [5210, 17298]}
# {159: [11387, 19458]}
# {160: [11472, 10056]}
# {161: [15780, 18166]}
# {162: [20461, 8742]}
# {163: [1632, 14266]}
# {164: [16248, 4060]}
# {165: [19100, 14238]}
# {166: [19052, 18381]}
# {167: [21828, 9853]}
# {168: [21570, 9824]}
# {169: [5951, 21816]}
# {170: [8422, 10638]}
# {171: [1734, 11374]}
# {172: [12017, 13034]}
# {173: [3971, 20609]}
# {174: [13110, 1624]}
# {175: [4592, 11496]}
# {176: [16355, 6601]}
# {177: [13481, 8947]}
# {178: [23578, 10253]}
# {179: [6406, 23924]}
# {180: [15069, 23312]}
# {181: [21500, 13065]}
# {182: [3009, 22437]}
# {183: [10659, 14421]}
# {184: [19477, 14704]}
# {185: [11491, 19780]}
# {186: [23246, 10795]}
# {187: [10745, 8924]}
# {188: [21397, 6278]}
# {189: [7070, 6596]}
# {190: [10100, 23827]}
# {191: [8203, 7289]}
# {192: [9106, 19120]}
# {193: [6773, 6481]}
# {194: [18005, 1238]}
# {195: [4003, 1090]}
# {196: [4967, 18214]}
# {197: [20552, 22408]}
# {198: [18962, 22496]}
# {199: [17233, 15398]}
# {200: [11891, 8720]}
# {201: [8389, 734]}
# {202: [2597, 22942]}
# {203: [22775, 361]}
# {204: [8038, 9796]}
# {205: [23485, 12586]}
# {206: [23881, 14561]}
# {207: [16109, 16122]}
# {208: [12018, 2497]}
# {209: [3444, 7461]}
# {210: [3443, 13888]}
# {211: [624, 902]}
# {212: [7451, 8331]}
# {213: [12281, 22144]}
# {214: [4559, 15568]}
# {215: [20343, 2949]}
# {216: [21559, 4996]}
# {217: [23548, 20579]}
# {218: [9031, 17960]}
# {219: [19142, 23375]}
# {220: [19876, 13958]}
# {221: [10558, 2833]}
# {222: [12047, 392]}
# {223: [4497, 17489]}
# {224: [15887, 7287]}
# {225: [19043, 16959]}
# {226: [16213, 23128]}
# {227: [10736, 14283]}
# {228: [19235, 15822]}
# {229: [14363, 13272]}
# {230: [22947, 9791]}
# {231: [14507, 8075]}
# {232: [7367, 7693]}
# {233: [1611, 4618]}
# {234: [13504, 17350]}
# {235: [7958, 22453]}
# {236: [15196, 5547]}
# {237: [3826, 5020]}
# {238: [22793, 16922]}
# {239: [13375, 2671]}
# {240: [15140, 3634]}
# {241: [13054, 1915]}
# {242: [5847, 16529]}
# {243: [16807, 21014]}
# {244: [10829, 450]}
# {245: [7972, 23263]}
# {246: [13558, 1725]}
# {247: [18371, 8280]}
# {248: [20354, 13826]}
# {249: [20759, 16566]}
# {250: [6233, 22780]}
# {251: [22735, 19497]}
# {252: [5695, 7390]}
# {253: [12424, 11988]}
# {254: [20724, 14356]}
# {255: [12546, 21271]}
# {256: [15384, 11459]}
# {257: [22339, 23177]}
# {258: [2735, 6128]}
# {259: [8144, 19198]}
# {260: [2850, 14530]}
# {261: [14039, 9397]}
# {262: [19375, 19480]}
# {263: [8643, 6779]}
# {264: [19915, 4829]}
# {265: [14383, 3832]}
# {266: [10018, 19385]}
# {267: [10627, 5915]}
# {268: [9864, 12247]}
# {269: [15395, 16990]}
# {270: [9285, 15327]}
# {271: [23218, 9298]}
# {272: [13754, 20061]}
# {273: [11126, 1711]}
# {274: [14515, 10665]}
# {275: [14982, 18789]}
# {276: [18332, 23835]}
# {277: [21415, 14007]}
# {278: [23504, 1573]}
# {279: [22443, 13710]}
# {280: [10203, 15680]}
# {281: [23799, 9053]}
# {282: [16675, 14543]}
# {283: [13771, 18110]}
# {284: [8960, 22531]}
# {285: [13848, 21147]}
# {286: [11110, 16780]}
# {287: [20431, 2182]}
# {288: [8945, 21248]}
# {289: [19016, 5403]}
# {290: [23848, 3984]}
# {291: [12575, 20119]}
# {292: [19631, 871]}
# {293: [21847, 9146]}
# {294: [2828, 22963]}
# {295: [1929, 3707]}
# {296: [13805, 4029]}
# {297: [12577, 15353]}
# {298: [4710, 11713]}
# {299: [18395, 7424]}
# {300: [7803, 4365]}
# {301: [16031, 1952]}
# {302: [13585, 9604]}
# {303: [21206, 4900]}
# {304: [556, 23316]}
# {305: [15058, 23556]}
# {306: [15295, 21056]}
# {307: [3126, 13008]}
# {308: [16293, 23524]}
# {309: [9865, 11012]}
# {310: [20387, 4001]}
# {311: [13333, 3511]}
# {312: [10001, 17367]}
# {313: [4956, 12495]}
# {314: [19862, 13937]}
# {315: [13253, 892]}
# {316: [10246, 20962]}
# {317: [7963, 9465]}
# {318: [4197, 6670]}
# {319: [23379, 10034]}
# {320: [17874, 14198]}
# {321: [5032, 20656]}
# {322: [6789, 6933]}
# {323: [15593, 22973]}
# {324: [6846, 2242]}
# {325: [15065, 2895]}
# {326: [643, 7526]}
# {327: [10158, 9375]}
# {328: [9609, 3025]}
# {329: [9562, 16258]}
# {330: [5693, 23033]}
# {331: [9059, 6273]}
# {332: [9828, 5330]}
# {333: [16900, 8241]}
# {334: [20097, 10377]}
# {335: [9244, 18519]}
# {336: [10390, 4458]}
# {337: [5505, 2904]}
# {338: [190, 15737]}
# {339: [4917, 22680]}
# {340: [7568, 16490]}
# {341: [10464, 16689]}
# {342: [8548, 22242]}
# {343: [20699, 20093]}
# {344: [9527, 18772]}
# {345: [4989, 20257]}
# {346: [21211, 14848]}
# {347: [1708, 10852]}
# {348: [17276, 871]}
# {349: [11435, 5683]}
# {350: [3809, 9459]}
# {351: [1841, 16010]}
# {352: [17466, 7798]}
# {353: [15942, 2094]}
# {354: [2831, 5317]}
# {355: [11285, 18674]}
# {356: [8057, 18646]}
# {357: [359, 11105]}
# {358: [10081, 15860]}
# {359: [18550, 9518]}
# {360: [19266, 8202]}
# {361: [9739, 2386]}
# {362: [3468, 12425]}
# {363: [5456, 22623]}
# {364: [21962, 5786]}
# {365: [16432, 19280]}
# {366: [20433, 17353]}
# {367: [6093, 9380]}
# {368: [17301, 8869]}
# {369: [12351, 3084]}
# {370: [13499, 9552]}
# {371: [21577, 7913]}
# {372: [14663, 6820]}
# {373: [18317, 18608]}
# {374: [8590, 849]}
# {375: [14333, 1669]}
# {376: [2852, 18627]}
# {377: [2891, 23294]}
# {378: [15447, 9749]}
# {379: [6504, 8393]}
# {380: [9642, 13710]}
# {381: [20939, 8560]}
# {382: [9929, 712]}
# {383: [19734, 1387]}
# {384: [1288, 18502]}
# {385: [2386, 4096]}
# {386: [9306, 9481]}
# {387: [6055, 22139]}
# {388: [17110, 3551]}
# {389: [648, 10108]}
# {390: [6642, 12870]}
# {391: [20266, 23516]}
# {392: [18763, 9910]}
# {393: [15607, 23365]}
# {394: [17926, 8092]}
# {395: [5428, 11552]}
# {396: [2023, 10998]}
# {397: [19711, 10738]}
# {398: [19233, 6398]}
# {399: [12008, 20947]}
# {400: [9136, 12177]}
# {401: [4392, 6865]}
# {402: [10850, 6542]}
# {403: [21027, 12222]}
# {404: [10191, 19950]}
# {405: [5791, 10832]}
# {406: [12834, 3921]}
# {407: [3259, 22765]}
# {408: [12116, 560]}
# {409: [19791, 19130]}
# {410: [620, 13145]}
# {411: [3175, 13638]}
# {412: [1006, 8241]}
# {413: [7227, 17929]}
# {414: [11859, 2369]}
# {415: [16520, 15228]}
# {416: [22312, 7004]}
# {417: [5443, 14046]}
# {418: [8519, 7704]}
# {419: [2473, 9418]}
# {420: [12223, 2419]}
# {421: [10986, 15752]}
# {422: [13018, 19451]}
# {423: [2184, 5293]}
# {424: [1562, 19930]}
# {425: [6517, 20852]}
# {426: [22215, 15285]}
# {427: [15195, 21693]}
# {428: [1695, 9466]}
# {429: [12151, 16101]}
# {430: [4160, 13900]}
# {431: [12963, 17519]}
# {432: [5515, 16992]}
# {433: [7008, 23909]}
# {434: [12890, 22514]}
# {435: [18912, 18781]}
# {436: [8864, 16867]}
# {437: [20294, 12439]}
# {438: [22473, 909]}
# {439: [11830, 19036]}
# {440: [7498, 6975]}
# {441: [17161, 9445]}
# {442: [8927, 9800]}
# {443: [23789, 18762]}
# {444: [8498, 9136]}
# {445: [14904, 4924]}
# {446: [6819, 9453]}
# {447: [21000, 23774]}
# {448: [18474, 14471]}
# {449: [18072, 10558]}
# {450: [17170, 6932]}
# {451: [19021, 18222]}
# {452: [18073, 22483]}
# {453: [4805, 6193]}
# {454: [21605, 4744]}
# {455: [2301, 18223]}
# {456: [14046, 7905]}
# {457: [5079, 17865]}
# {458: [14362, 16465]}
# {459: [355, 17044]}
# {460: [1594, 16091]}
# {461: [12181, 15668]}
# {462: [8255, 4792]}
# {463: [11784, 14626]}
# {464: [23788, 11515]}
# {465: [21245, 11098]}
# {466: [13954, 20873]}
# {467: [6826, 15491]}
# {468: [22801, 15566]}
# {469: [128, 896]}
# {470: [3942, 10844]}
# {471: [13311, 1386]}
# {472: [3208, 20465]}
# {473: [19904, 8329]}
# {474: [9733, 10895]}
# {475: [18183, 20715]}
# {476: [17735, 2050]}
# {477: [10295, 13228]}
# {478: [6200, 23887]}
# {479: [15391, 18417]}
# {480: [1195, 3603]}
# {481: [8343, 12284]}
# {482: [19724, 8296]}
# {483: [2771, 20191]}
# {484: [18325, 20763]}
# {485: [21147, 21926]}
# {486: [15626, 20178]}
# {487: [20590, 16598]}
# {488: [13807, 17229]}
# {489: [15035, 21836]}
# {490: [2336, 3121]}
# {491: [8462, 20330]}
# {492: [22285, 10125]}
# {493: [21878, 18830]}
# {494: [20742, 15571]}
# {495: [16420, 5339]}
# {496: [10994, 4022]}
# {497: [1212, 13658]}
# {498: [19445, 3825]}
# {499: [23443, 21162]}
# {500: [17971, 18731]}
# {501: [23929, 7472]}
# {502: [8074, 22671]}
# {503: [8937, 17799]}
# {504: [19584, 19465]}
# {505: [2190, 20493]}
# {506: [15218, 19694]}
# {507: [22718, 3570]}
# {508: [15868, 8234]}
# {509: [7095, 17560]}
# {510: [8553, 8490]}
# {511: [2139, 8286]}
# {512: [7034, 11700]}
# {513: [10915, 991]}
# {514: [21233, 8318]}
# {515: [20624, 20883]}
# {516: [20336, 17271]}
# {517: [6494, 4949]}
# {518: [15743, 1315]}
# {519: [11521, 17998]}
# {520: [13834, 21886]}
# {521: [21978, 22498]}
# {522: [3656, 3391]}
# {523: [16852, 7798]}
# {524: [5478, 12358]}
# {525: [1239, 1176]}
# {526: [3723, 19729]}
# {527: [7699, 17215]}
# {528: [16137, 15932]}
# {529: [16827, 21339]}
# {530: [7646, 12035]}
# {531: [13288, 16960]}
# {532: [6162, 14151]}
# {533: [12690, 2295]}
# {534: [15525, 18760]}
# {535: [7500, 11188]}
# {536: [20686, 8471]}
# {537: [11265, 11396]}
# {538: [21903, 18713]}
# {539: [19028, 1916]}
# {540: [10145, 14367]}
# {541: [21574, 8522]}
# {542: [12448, 17210]}
# {543: [11140, 11206]}
# {544: [12279, 22355]}
# {545: [2231, 519]}
# {546: [1202, 415]}
# {547: [50, 793]}
# {548: [2232, 2683]}
# {549: [1642, 7344]}
# {550: [7401, 6961]}
# {551: [10366, 11638]}
# {552: [4762, 23714]}
# {553: [21447, 16339]}
# {554: [7893, 9952]}
# {555: [21827, 53]}
# {556: [14219, 5984]}
# {557: [7139, 22770]}
# {558: [23518, 12081]}
# {559: [22321, 17727]}
# {560: [8662, 8736]}
# {561: [21654, 19023]}
# {562: [2588, 14526]}
# {563: [17884, 15323]}
# {564: [18228, 18475]}
# {565: [18922, 11384]}
# {566: [9378, 3900]}
# {567: [17348, 17267]}
# {568: [5447, 7540]}
# {569: [2515, 18420]}
# {570: [241, 18022]}
# {571: [22967, 7331]}
# {572: [21044, 9516]}
# {573: [5081, 9780]}
# {574: [18551, 10197]}
# {575: [10930, 14681]}
# {576: [21836, 10005]}
# {577: [9540, 8920]}
# {578: [2208, 7996]}
# {579: [22384, 22450]}
# {580: [21647, 20310]}
# {581: [17350, 3369]}
# {582: [16550, 23609]}
# {583: [16696, 41]}
# {584: [16757, 11468]}
# {585: [10417, 4929]}
# {586: [4834, 20270]}
# {587: [4873, 21686]}
# {588: [18674, 4710]}
# {589: [14402, 17414]}
# {590: [201, 3092]}
# {591: [15724, 22390]}
# {592: [15226, 9171]}
# {593: [6929, 3979]}
# {594: [4092, 18732]}
# {595: [21829, 20571]}
# {596: [3868, 23221]}
# {597: [22647, 12852]}
# {598: [2296, 3147]}
# {599: [18002, 10644]}
# {600: [3762, 1899]}
# {601: [19494, 7726]}
# {602: [4490, 20774]}
# {603: [2572, 13071]}
# {604: [2922, 833]}
# {605: [5954, 23270]}
# {606: [23795, 4099]}
# {607: [10476, 8786]}
# {608: [5521, 3841]}
# {609: [15702, 3166]}
# {610: [15141, 6027]}
# {611: [13136, 3897]}
# {612: [218, 13454]}
# {613: [21128, 3399]}
# {614: [17149, 13487]}
# {615: [22597, 17144]}
# {616: [15151, 19063]}
# {617: [23180, 20757]}
# {618: [22659, 13690]}
# {619: [11308, 21296]}
# {620: [1027, 11849]}
# {621: [9392, 933]}
# {622: [13932, 22141]}
# {623: [5671, 8683]}
# {624: [23678, 14435]}
# {625: [21518, 5846]}
# {626: [9246, 21772]}
# {627: [12780, 2776]}
# {628: [19348, 20327]}
# {629: [7936, 7378]}
# {630: [12218, 7957]}
# {631: [23906, 19157]}
# {632: [18853, 19699]}
# {633: [22917, 4113]}
# {634: [17797, 15513]}
# {635: [8209, 2728]}
# {636: [2993, 2349]}
# {637: [6032, 13981]}
# {638: [6187, 2586]}
# {639: [19091, 7330]}
# {640: [11536, 20266]}
# {641: [18637, 15885]}
# {642: [16565, 654]}
# {643: [22750, 15809]}
# {644: [8654, 14366]}
# {645: [21783, 21768]}
# {646: [3609, 13914]}
# {647: [11961, 14776]}
# {648: [12232, 20150]}
# {649: [11130, 4558]}
# {650: [10982, 9353]}
# {651: [11055, 23110]}
# {652: [3382, 22734]}
# {653: [18129, 5592]}
# {654: [17901, 22177]}
# {655: [9816, 15466]}
# {656: [7372, 6376]}
# {657: [9022, 22435]}
# {658: [17026, 293]}
# {659: [11663, 1661]}
# {660: [22536, 10823]}
# {661: [11132, 4324]}
# {662: [22144, 22403]}
# {663: [17887, 3456]}
# {664: [10494, 14639]}
# {665: [3391, 6173]}
# {666: [15673, 264]}
# {667: [18991, 13328]}
# {668: [4236, 17443]}
# {669: [6028, 602]}
# {670: [15877, 10271]}
# {671: [15301, 6600]}
# {672: [15686, 8685]}
# {673: [3041, 445]}
# {674: [13436, 18959]}
# {675: [16576, 17323]}
# {676: [11501, 15314]}
# {677: [5953, 13183]}
# {678: [5723, 15339]}
# {679: [8697, 8618]}
# {680: [22066, 206]}
# {681: [5644, 14168]}
# {682: [23516, 9945]}
# {683: [19322, 14812]}
# {684: [2397, 3524]}
# {685: [16912, 7931]}
# {686: [4108, 20551]}
# {687: [22261, 12997]}
# {688: [7634, 4499]}
# {689: [5396, 10833]}
# {690: [18539, 1474]}
# {691: [11196, 19470]}
# {692: [10872, 2693]}
# {693: [21833, 20667]}
# {694: [12749, 15504]}
# {695: [22956, 1844]}
# {696: [2859, 20893]}
# {697: [10375, 9170]}
# {698: [22561, 23652]}
# {699: [4308, 4242]}
# {700: [342, 9163]}
# {701: [11587, 23355]}
# {702: [17629, 21471]}
# {703: [1, 23979]}
# {704: [17367, 6656]}
# {705: [6910, 9853]}
# {706: [2858, 9852]}
# {707: [4742, 972]}
# {708: [20526, 7891]}
# {709: [5852, 7662]}
# {710: [23162, 3350]}
# {711: [21784, 18547]}
# {712: [6293, 19135]}
# {713: [14246, 15902]}
# {714: [21250, 2144]}
# {715: [15049, 18902]}
# {716: [707, 4007]}
# {717: [1122, 14908]}
# {718: [19247, 5497]}
# {719: [9901, 7800]}
# {720: [8849, 10194]}
# {721: [4273, 972]}
# {722: [16808, 8201]}
# {723: [4880, 13359]}
# {724: [20269, 11079]}
# {725: [2927, 9885]}
# {726: [21731, 18782]}
# {727: [17546, 18267]}
# {728: [705, 5721]}
# {729: [11483, 20005]}
# {730: [15393, 6115]}
# {731: [9638, 9410]}
# {732: [1128, 15220]}
# {733: [402, 11292]}
# {734: [22369, 14395]}
# {735: [7522, 22262]}
# {736: [15546, 20480]}
# {737: [6570, 19472]}
# {738: [20038, 12269]}
# {739: [18619, 9018]}
# {740: [16877, 21355]}
# {741: [2928, 16566]}
# {742: [20705, 18273]}
# {743: [10919, 21510]}
# {744: [6124, 8535]}
# {745: [2411, 15386]}
# {746: [22002, 5024]}
# {747: [6697, 22206]}
# {748: [14846, 4295]}
# {749: [20376, 18282]}
# {750: [4668, 5109]}
# {751: [6446, 15080]}
# {752: [16437, 3756]}
# {753: [1528, 12]}
# {754: [4659, 4605]}
# {755: [3195, 8359]}
# {756: [6075, 15740]}
# {757: [17018, 21057]}
# {758: [12929, 16322]}
# {759: [5057, 23974]}
# {760: [19060, 4642]}
# {761: [20977, 13699]}
# {762: [23223, 18923]}
# {763: [5997, 18160]}
# {764: [3248, 5928]}
# {765: [16207, 16567]}
# {766: [5285, 11975]}
# {767: [2952, 8711]}
# {768: [4556, 14194]}
# {769: [15116, 18823]}
# {770: [21353, 16480]}
# {771: [12542, 19698]}
# {772: [2350, 5775]}
# {773: [10839, 23539]}
# {774: [23941, 14013]}
# {775: [21327, 21848]}
# {776: [17528, 2030]}
# {777: [7877, 7577]}
# {778: [17772, 9359]}
# {779: [17429, 10585]}
# {780: [1500, 3805]}
# {781: [17136, 1458]}
# {782: [19114, 6729]}
# {783: [7098, 10857]}
# {784: [21236, 13335]}
# {785: [17826, 10182]}
# {786: [17613, 21907]}
# {787: [5798, 8561]}
# {788: [6199, 21356]}
# {789: [10861, 1999]}
# {790: [22247, 7241]}
# {791: [1820, 7713]}
# {792: [17871, 13725]}
# {793: [15734, 22915]}
# {794: [1349, 13977]}
# {795: [6873, 15404]}
# {796: [10025, 14431]}
# {797: [284, 2894]}
# {798: [18901, 16478]}
# {799: [19071, 23225]}
# {800: [13923, 16477]}
# {801: [2420, 1957]}
# {802: [16232, 11629]}
# {803: [16679, 4640]}
# {804: [4731, 19357]}
# {805: [7051, 727]}
# {806: [17641, 9963]}
# {807: [22492, 5413]}
# {808: [12837, 1663]}
# {809: [15904, 9816]}
# {810: [6673, 15601]}
# {811: [11318, 13013]}
# {812: [17177, 23910]}
# {813: [9160, 18123]}
# {814: [12119, 3633]}
# {815: [11230, 20516]}
# {816: [12177, 12266]}
# {817: [14428, 23061]}
# {818: [8588, 20920]}
# {819: [5371, 21309]}
# {820: [21230, 3185]}
# {821: [1660, 17431]}
# {822: [16841, 9589]}
# {823: [10805, 18500]}
# {824: [18594, 19587]}
# {825: [22105, 13435]}
# {826: [22529, 6111]}
# {827: [2013, 10600]}
# {828: [4410, 10133]}
# {829: [5518, 4996]}
# {830: [17947, 12129]}
# {831: [2513, 22789]}
# {832: [14211, 12043]}
# {833: [13142, 690]}
# {834: [17285, 14373]}
# {835: [14903, 6635]}
# {836: [14500, 481]}
# {837: [22535, 16033]}
# {838: [14052, 10962]}
# {839: [21581, 14518]}
# {840: [1720, 13152]}
# {841: [2542, 9434]}
# {842: [1793, 429]}
# {843: [5046, 17730]}
# {844: [20435, 20771]}
# {845: [3078, 23477]}
# {846: [21952, 15392]}
# {847: [20565, 8382]}
# {848: [17243, 23026]}
# {849: [22313, 16212]}
# {850: [12107, 22497]}
# {851: [17180, 13401]}
# {852: [336, 16503]}
# {853: [2055, 5593]}
# {854: [22514, 20194]}
# {855: [5111, 6369]}
# {856: [7090, 2471]}
# {857: [5017, 23343]}
# {858: [16149, 5913]}
# {859: [17408, 10229]}
# {860: [1874, 14079]}
# {861: [12671, 5357]}
# {862: [7497, 17537]}
# {863: [8932, 12321]}
# {864: [11490, 22887]}
# {865: [18803, 10893]}
# {866: [15120, 9417]}
# {867: [21987, 13256]}
# {868: [13064, 20509]}
# {869: [10054, 3672]}
# {870: [18570, 15154]}
# {871: [14343, 15511]}
# {872: [14348, 4348]}
# {873: [12484, 4590]}
# {874: [9569, 1016]}
# {875: [3305, 12408]}
# {876: [5987, 4481]}
# {877: [9941, 20704]}
# {878: [7248, 292]}
# {879: [22954, 8714]}
# {880: [10179, 8408]}
# {881: [10149, 874]}
# {882: [8423, 587]}
# {883: [19224, 14128]}
# {884: [10452, 23855]}
# {885: [15423, 16347]}
# {886: [13644, 16183]}
# {887: [18635, 18236]}
# {888: [16371, 3112]}
# {889: [19758, 17152]}
# {890: [14440, 11861]}
# {891: [2462, 22045]}
# {892: [5216, 21436]}
# {893: [5718, 10909]}
# {894: [18865, 6210]}
# {895: [10370, 11567]}
# {896: [9862, 18658]}
# {897: [17140, 10413]}
# {898: [17452, 21910]}
# {899: [12434, 12796]}
# {900: [16196, 16440]}
# {901: [8677, 15293]}
# {902: [14620, 8475]}
# {903: [4117, 18998]}
# {904: [22684, 14306]}
# {905: [15072, 13308]}
# {906: [12507, 14027]}
# {907: [20241, 4026]}
# {908: [8148, 2286]}
# {909: [20429, 5214]}
# {910: [12689, 10337]}
# {911: [5507, 8359]}
# {912: [10112, 19625]}
# {913: [7654, 19515]}
# {914: [2644, 6748]}
# {915: [16901, 19847]}
# {916: [19475, 17222]}
# {917: [19613, 21318]}
# {918: [1004, 18929]}
# {919: [9358, 3748]}
# {920: [12673, 324]}
# {921: [22065, 13170]}
# {922: [6777, 7142]}
# {923: [22039, 13930]}
# {924: [18785, 11680]}
# {925: [11915, 16126]}
# {926: [876, 19383]}
# {927: [7776, 16191]}
# {928: [10087, 3030]}
# {929: [21131, 17862]}
# {930: [6083, 16259]}
# {931: [5335, 2309]}
# {932: [1998, 8708]}
# {933: [21199, 17136]}
# {934: [8330, 13777]}
# {935: [11557, 1192]}
# {936: [14356, 6333]}
# {937: [10688, 18085]}
# {938: [65, 15965]}
# {939: [21135, 19450]}
# {940: [6803, 78]}
# {941: [2220, 199]}
# {942: [17977, 14251]}
# {943: [3526, 16918]}
# {944: [16263, 8571]}
# {945: [17521, 7053]}
# {946: [5637, 3204]}
# {947: [15260, 2092]}
# {948: [21404, 21238]}
# {949: [14258, 16205]}
# {950: [6370, 5119]}
# {951: [1453, 19876]}
# {952: [5128, 18724]}
# {953: [13648, 5295]}
# {954: [7645, 18800]}
# {955: [11519, 2378]}
# {956: [17415, 16049]}
# {957: [9550, 22410]}
# {958: [7575, 13612]}
# {959: [12276, 1595]}
# {960: [18399, 12579]}
# {961: [16120, 10421]}
# {962: [21474, 3134]}
# {963: [5176, 17445]}
# {964: [4635, 6504]}
# {965: [2026, 743]}
# {966: [18053, 7598]}
# {967: [14520, 8225]}
# {968: [6488, 5095]}
# {969: [14925, 14804]}
# {970: [12867, 6414]}
# {971: [18719, 3403]}
# {972: [7088, 10970]}
# {973: [19642, 6439]}
# {974: [14581, 9007]}
# {975: [6310, 16262]}
# {976: [13390, 10252]}
# {977: [4987, 18045]}
# {978: [23261, 11652]}
# {979: [6760, 4383]}
# {980: [16332, 3453]}
# {981: [2964, 9986]}
# {982: [5660, 3857]}
# {983: [4188, 15741]}
# {984: [9122, 18359]}
# {985: [14384, 11736]}
# {986: [3845, 2159]}
# {987: [22768, 2836]}
# {988: [13522, 23776]}
# {989: [4706, 18472]}
# {990: [13856, 22017]}
# {991: [330, 21341]}
# {992: [5400, 16136]}
# {993: [8801, 8038]}
# {994: [104, 4512]}
# {995: [19365, 23939]}
# {996: [14688, 22831]}
# {997: [5009, 12530]}
# {998: [9027, 13541]}
# {999: [3647, 18733]}
# {1000: [16709, 16837]}
# {1001: [294, 7415]}
# {1002: [6239, 20048]}
# {1003: [8644, 13026]}
# {1004: [3330, 23863]}
# {1005: [849, 19277]}
# {1006: [22106, 14540]}
# {1007: [18543, 10585]}
# {1008: [21501, 8925]}
# {1009: [17896, 14123]}
# {1010: [9012, 2056]}
# {1011: [8359, 19350]}
# {1012: [21407, 8990]}
# {1013: [21283, 12442]}
# {1014: [13097, 23501]}
# {1015: [10907, 18381]}
# {1016: [10357, 7974]}
# {1017: [6811, 7017]}
# {1018: [6356, 14075]}
# {1019: [4905, 16280]}
# {1020: [2691, 16447]}
# {1021: [19270, 21384]}
# {1022: [12675, 11216]}
# {1023: [90, 11509]}
# {1024: [18734, 15798]}
# {1025: [19111, 16476]}
# {1026: [19926, 22529]}
# {1027: [8318, 12270]}
# {1028: [23699, 20447]}
# {1029: [3493, 17117]}
# {1030: [17130, 14964]}
# {1031: [7553, 1751]}
# {1032: [13957, 603]}
# {1033: [23794, 3952]}
# {1034: [21417, 15193]}
# {1035: [18206, 17899]}
# {1036: [18810, 12168]}
# {1037: [14149, 13822]}
# {1038: [17688, 18020]}
# {1039: [4478, 17278]}
# {1040: [21200, 16636]}
# {1041: [18571, 14732]}
# {1042: [15944, 13831]}
# {1043: [18078, 3722]}
# {1044: [14072, 18679]}
# {1045: [18792, 15760]}
# {1046: [14190, 9854]}
# {1047: [6037, 13678]}
# {1048: [13268, 4440]}
# {1049: [5835, 6585]}
# {1050: [19654, 23198]}
# {1051: [9554, 6818]}
# {1052: [12859, 8776]}
# {1053: [18693, 5468]}
# {1054: [17770, 10790]}
# {1055: [21251, 19708]}
# {1056: [20885, 18985]}
# {1057: [4441, 13344]}
# {1058: [4458, 17067]}
# {1059: [23557, 13310]}
# {1060: [14087, 12357]}
# {1061: [4246, 16041]}
# {1062: [12642, 15748]}
# {1063: [21765, 22084]}
# {1064: [1872, 9101]}
# {1065: [20380, 14352]}
# {1066: [3873, 15148]}
# {1067: [19335, 437]}
# {1068: [19153, 15764]}
# {1069: [14639, 1303]}
# {1070: [3537, 1676]}
# {1071: [4397, 19425]}
# {1072: [23326, 20752]}
# {1073: [6580, 407]}
# {1074: [6969, 15317]}
# {1075: [5364, 11261]}
# {1076: [7387, 22811]}
# {1077: [11034, 5457]}
# {1078: [7587, 3361]}
# {1079: [11337, 19132]}
# {1080: [21902, 3534]}
# {1081: [13769, 1079]}
# {1082: [11733, 18261]}
# {1083: [18817, 3448]}
# {1084: [512, 18064]}
# {1085: [14859, 1138]}
# {1086: [9812, 16932]}
# {1087: [9799, 15447]}
# {1088: [971, 5705]}
# {1089: [1286, 15907]}
# {1090: [7664, 10518]}
# {1091: [18883, 14435]}
# {1092: [8039, 3178]}
# {1093: [16873, 19302]}
# {1094: [18950, 6134]}
# {1095: [19540, 7103]}
# {1096: [21297, 1427]}
# {1097: [13071, 20771]}
# {1098: [9301, 13027]}
# {1099: [22407, 6328]}
# {1100: [22150, 2485]}
# {1101: [20632, 2232]}
# {1102: [15653, 152]}
# {1103: [12781, 13759]}
# {1104: [2138, 8885]}
# {1105: [19738, 13670]}
# {1106: [18578, 1952]}
# {1107: [10268, 31]}
# {1108: [5541, 21060]}
# {1109: [10231, 6313]}
# {1110: [23721, 13021]}
# {1111: [11345, 10976]}
# {1112: [13908, 9619]}
# {1113: [3150, 4564]}
# {1114: [5645, 15949]}
# {1115: [6815, 20290]}
# {1116: [13933, 11773]}
# {1117: [1249, 198]}
# {1118: [6346, 12948]}
# {1119: [21585, 16838]}
# {1120: [12519, 9643]}
# {1121: [5500, 18745]}
# {1122: [9238, 12913]}
# {1123: [23753, 10126]}
# {1124: [4600, 11497]}
# {1125: [3438, 1340]}
# {1126: [18254, 20759]}
# {1127: [8118, 6267]}
# {1128: [18351, 10728]}
# {1129: [19083, 18027]}
# {1130: [18880, 21850]}
# {1131: [5138, 9180]}
# {1132: [1395, 19107]}
# {1133: [14439, 9476]}
# {1134: [19417, 6151]}
# {1135: [22186, 14041]}
# {1136: [22623, 4929]}
# {1137: [21710, 10665]}
# {1138: [22193, 1522]}
# {1139: [7998, 21877]}
# {1140: [2863, 2247]}
# {1141: [13053, 3664]}
# {1142: [1644, 20859]}
# {1143: [7092, 20670]}
# {1144: [13619, 1435]}
# {1145: [17900, 23653]}
# {1146: [19352, 3190]}
# {1147: [16640, 5870]}
# {1148: [20897, 390]}
# {1149: [21336, 17671]}
# {1150: [16922, 23456]}
# {1151: [21523, 4029]}
# {1152: [11547, 13806]}
# {1153: [3061, 1007]}
# {1154: [17036, 15186]}
# {1155: [13949, 15013]}
# {1156: [11996, 11778]}
# {1157: [21, 19342]}
# {1158: [3365, 22084]}
# {1159: [4131, 9011]}
# {1160: [642, 7734]}
# {1161: [22759, 6978]}
# {1162: [4132, 16852]}
# {1163: [19081, 16078]}
# {1164: [11856, 2008]}
# {1165: [10422, 15264]}
# {1166: [17974, 17923]}
# {1167: [6038, 12499]}
# {1168: [13334, 241]}
# {1169: [18509, 12872]}
# {1170: [18030, 247]}
# {1171: [23465, 18723]}
# {1172: [20910, 11605]}
# {1173: [1942, 1649]}
# {1174: [17340, 20359]}
# {1175: [9622, 3395]}
# {1176: [20627, 19226]}
# {1177: [23671, 19741]}
# {1178: [17828, 13168]}
# {1179: [20945, 22382]}
# {1180: [14201, 14075]}
# {1181: [10761, 17407]}
# {1182: [15733, 20915]}
# {1183: [11093, 6544]}
# {1184: [3247, 15214]}
# {1185: [10965, 2772]}
# {1186: [12787, 8471]}
# {1187: [6048, 18289]}
# {1188: [5195, 18527]}
# {1189: [6159, 14959]}
# {1190: [12407, 22845]}
# {1191: [21377, 22942]}
# {1192: [18003, 5600]}
# {1193: [20808, 18797]}
# {1194: [9712, 23645]}
# {1195: [1497, 18675]}
# {1196: [21707, 17353]}
# {1197: [23693, 15294]}
# {1198: [3998, 13864]}
# {1199: [18576, 6556]}
# {1200: [22127, 16748]}
# {1201: [22209, 5069]}
# {1202: [4972, 11906]}
# {1203: [15849, 4558]}
# {1204: [3010, 20698]}
# {1205: [20035, 5839]}
# {1206: [8417, 19659]}
# {1207: [3182, 11605]}
# {1208: [19123, 9710]}
# {1209: [3743, 20201]}
# {1210: [1013, 286]}
# {1211: [1009, 16910]}
# {1212: [11158, 11855]}
# {1213: [11807, 19675]}
# {1214: [22767, 14300]}
# {1215: [14815, 10853]}
# {1216: [11763, 14170]}
# {1217: [20308, 16311]}
# {1218: [109, 18932]}
# {1219: [12411, 4844]}
# {1220: [9961, 11167]}
# {1221: [2093, 6521]}
# {1222: [5941, 13160]}
# {1223: [3909, 17060]}
# {1224: [11609, 16629]}
# {1225: [7925, 2306]}
# {1226: [4202, 234]}
# {1227: [7861, 15595]}
# {1228: [11923, 9661]}
# {1229: [19389, 23490]}
# {1230: [7749, 12701]}
# {1231: [12124, 16992]}
# {1232: [15193, 18736]}
# {1233: [4499, 7962]}
# {1234: [1385, 4802]}
# {1235: [1300, 12289]}
# {1236: [4621, 23270]}
# {1237: [10555, 10606]}
# {1238: [8398, 16435]}
# {1239: [14069, 10868]}
# {1240: [17351, 11811]}
# {1241: [15143, 11257]}
# {1242: [15596, 6672]}
# {1243: [18232, 8056]}
# {1244: [669, 16002]}
# {1245: [3846, 10016]}
# {1246: [20504, 13838]}
# {1247: [15474, 23603]}
# {1248: [19571, 12819]}
# {1249: [13808, 20393]}
# {1250: [14875, 9470]}
# {1251: [14445, 13540]}
# {1252: [17261, 10428]}
# {1253: [16272, 299]}
# {1254: [14752, 4665]}
# {1255: [1892, 5700]}
# {1256: [15414, 21543]}
# {1257: [6264, 21072]}
# {1258: [23361, 11842]}
# {1259: [12120, 386]}
# {1260: [15154, 4405]}
# {1261: [21906, 7256]}
# {1262: [952, 6586]}
# {1263: [5673, 17999]}
# {1264: [12133, 21758]}
# {1265: [17021, 14552]}
# {1266: [10024, 8342]}
# {1267: [1831, 2575]}
# {1268: [15961, 7390]}
# {1269: [10777, 2447]}
# {1270: [21852, 15819]}
# {1271: [1518, 15132]}
# {1272: [1627, 23842]}
# {1273: [11675, 11343]}
# {1274: [7905, 15167]}
# {1275: [14862, 11506]}
# {1276: [17766, 5719]}
# {1277: [14616, 18307]}
# {1278: [21660, 21753]}
# {1279: [7158, 3301]}
# {1280: [21203, 18508]}
# {1281: [21533, 21306]}
# {1282: [1496, 1516]}
# {1283: [428, 288]}
# {1284: [362, 23251]}
# {1285: [3183, 4184]}
# {1286: [12600, 18649]}
# {1287: [8360, 6839]}
# {1288: [21529, 19531]}
# {1289: [13046, 17751]}
# {1290: [4602, 15836]}
# {1291: [19994, 22944]}
# {1292: [3192, 13234]}
# {1293: [8260, 1659]}
# {1294: [160, 15784]}
# {1295: [6132, 11200]}
# {1296: [20094, 7759]}
# {1297: [22557, 11102]}
# {1298: [8587, 22611]}
# {1299: [4876, 2605]}
# {1300: [6861, 18376]}
# {1301: [22409, 4366]}
# {1302: [6203, 16206]}
# {1303: [16650, 12386]}
# {1304: [7258, 21790]}
# {1305: [9668, 16434]}
# {1306: [2546, 22111]}
# {1307: [16522, 21776]}
# {1308: [14744, 20734]}
# {1309: [7073, 2675]}
# {1310: [925, 15941]}
# {1311: [594, 7023]}
# {1312: [4990, 6542]}
# {1313: [5218, 12570]}
# {1314: [18501, 9901]}
# {1315: [7289, 14475]}
# {1316: [9978, 16645]}
# {1317: [4643, 9539]}
# {1318: [18926, 15675]}
# {1319: [4828, 14640]}
# {1320: [22185, 7529]}
# {1321: [15408, 16348]}
# {1322: [21045, 13555]}
# {1323: [3462, 6748]}
# {1324: [3806, 1821]}
# {1325: [13831, 1949]}
# {1326: [20622, 7222]}
# {1327: [7572, 7520]}
# {1328: [7981, 22606]}
# {1329: [16139, 7887]}
# {1330: [6751, 16201]}
# {1331: [4468, 17579]}
# {1332: [10316, 4359]}
# {1333: [14210, 21204]}
# {1334: [23150, 22187]}
# {1335: [14873, 2270]}
# {1336: [9939, 13036]}
# {1337: [21349, 22116]}
# {1338: [23392, 3379]}
# {1339: [10125, 19047]}
# {1340: [1650, 4616]}
# {1341: [18936, 5584]}
# {1342: [16287, 12059]}
# {1343: [3069, 15327]}
# {1344: [4080, 12308]}
# {1345: [7338, 856]}
# {1346: [23537, 23826]}
# {1347: [15109, 9064]}
# {1348: [7521, 14058]}
# {1349: [22855, 20063]}
# {1350: [13963, 4917]}
# {1351: [18703, 3768]}
# {1352: [19638, 23172]}
# {1353: [838, 3115]}
# {1354: [18513, 3412]}
# {1355: [5988, 5127]}
# {1356: [16005, 22162]}
# {1357: [11123, 16331]}
# {1358: [3641, 21187]}
# {1359: [20957, 13709]}
# {1360: [15661, 14735]}
# {1361: [20694, 4177]}
# {1362: [4648, 3739]}
# {1363: [5271, 6059]}
# {1364: [12027, 7125]}
# {1365: [17983, 11343]}
# {1366: [23202, 20887]}
# {1367: [19444, 22309]}
# {1368: [2268, 16824]}
# {1369: [13496, 14199]}
# {1370: [5752, 2141]}
# {1371: [8458, 9273]}
# {1372: [12865, 23908]}
# {1373: [19529, 20092]}
# {1374: [15145, 831]}
# {1375: [9623, 4152]}
# {1376: [12766, 10115]}
# {1377: [17953, 22813]}
# {1378: [5509, 14451]}
# {1379: [18565, 23699]}
# {1380: [16763, 17792]}
# {1381: [387, 9821]}
# {1382: [16082, 20596]}
# {1383: [20898, 15996]}
# {1384: [21569, 13066]}
# {1385: [18784, 3944]}
# {1386: [3200, 14900]}
# {1387: [14293, 1403]}
# {1388: [3640, 12250]}
# {1389: [3045, 23080]}
# {1390: [3002, 14848]}
# {1391: [6367, 12806]}
# {1392: [358, 474]}
# {1393: [11288, 2900]}
# {1394: [3683, 6810]}
# {1395: [13265, 22774]}
# {1396: [4528, 16096]}
# {1397: [20477, 18450]}
# {1398: [17932, 7424]}
# {1399: [18729, 22461]}
# {1400: [7149, 16099]}
# {1401: [17727, 12591]}
# {1402: [4512, 15140]}
# {1403: [13980, 1198]}
# {1404: [7, 1039]}
# {1405: [11771, 2322]}
# {1406: [12657, 7195]}
# {1407: [1604, 5421]}
# {1408: [14062, 23167]}
# {1409: [4705, 15758]}
# {1410: [12189, 23332]}
# {1411: [12779, 5034]}
# {1412: [14267, 13494]}
# {1413: [2541, 12900]}
# {1414: [21086, 11661]}
# {1415: [8604, 4042]}
# {1416: [1043, 17030]}
# {1417: [2, 4]}
# {1418: [13353, 22029]}
# {1419: [16334, 21928]}
# {1420: [1117, 10481]}
# {1421: [22943, 7909]}
# {1422: [11737, 13316]}
# {1423: [17889, 12680]}
# {1424: [12462, 3797]}
# {1425: [22238, 12713]}
# {1426: [5882, 20522]}
# {1427: [846, 11491]}
# {1428: [23804, 8956]}
# {1429: [6687, 22226]}
# {1430: [4728, 7433]}
# {1431: [18256, 18423]}
# {1432: [20005, 8212]}
# {1433: [11155, 14873]}
# {1434: [19516, 15014]}
# {1435: [2956, 6435]}
# {1436: [3767, 13815]}
# {1437: [826, 1552]}
# {1438: [5756, 2742]}
# {1439: [14966, 23009]}
# {1440: [12742, 15203]}
# {1441: [23402, 15272]}
# {1442: [10671, 11435]}
# {1443: [9194, 7929]}
# {1444: [1441, 12193]}
# {1445: [1543, 4411]}
# {1446: [23457, 10072]}
# {1447: [10135, 1158]}
# {1448: [17281, 15331]}
# {1449: [22418, 16879]}
# {1450: [14259, 3941]}
# {1451: [23971, 23092]}
# {1452: [21667, 1853]}
# {1453: [12633, 8383]}
# {1454: [19590, 19452]}
# {1455: [13607, 20033]}
# {1456: [22148, 4820]}
# {1457: [20047, 22309]}
# {1458: [12634, 19952]}
# {1459: [13586, 2319]}
# {1460: [454, 19828]}
# {1461: [10095, 21563]}
# {1462: [14998, 7557]}
# {1463: [23782, 16159]}
# {1464: [9488, 7823]}
# {1465: [15664, 9603]}
# {1466: [3242, 5246]}
# {1467: [13896, 18092]}
# {1468: [1839, 1685]}
# {1469: [1469, 20891]}
# {1470: [796, 3240]}
# {1471: [9903, 20393]}
# {1472: [18776, 3385]}
# {1473: [17547, 17047]}
# {1474: [1152, 1507]}
# {1475: [15950, 8047]}
# {1476: [11295, 5084]}
# {1477: [1265, 14715]}
# {1478: [11462, 16560]}
# {1479: [3311, 6624]}
# {1480: [11247, 12171]}
# {1481: [17630, 1163]}
# {1482: [3119, 17914]}
# {1483: [18333, 9584]}
# {1484: [20248, 9385]}
# {1485: [13358, 23632]}
# {1486: [19373, 7131]}
# {1487: [20758, 20272]}
# {1488: [1689, 296]}
# {1489: [972, 10477]}
# {1490: [18669, 11022]}
# {1491: [19450, 19234]}
# {1492: [23471, 2518]}
# {1493: [10603, 19125]}
# {1494: [17525, 22784]}
# {1495: [18167, 10903]}
# {1496: [6262, 5393]}
# {1497: [17998, 5164]}
# {1498: [3724, 12888]}
# {1499: [17959, 23493]}
# {1500: [14416, 17215]}
# {1501: [21517, 23053]}
# {1502: [23701, 12423]}
# {1503: [17583, 7852]}
# {1504: [14977, 21498]}
# {1505: [44, 16576]}
# {1506: [22602, 21460]}
# {1507: [4376, 23721]}
# {1508: [499, 21416]}
# {1509: [15436, 16411]}
# {1510: [16472, 619]}
# {1511: [1981, 23889]}
# {1512: [12566, 4145]}
# {1513: [19154, 6227]}
# {1514: [19750, 5342]}
# {1515: [17790, 3470]}
# {1516: [19490, 12730]}
# {1517: [16359, 844]}
# {1518: [5611, 7157]}
# {1519: [21095, 17026]}
# {1520: [11419, 12598]}
# {1521: [22438, 20625]}
# {1522: [14277, 5556]}
# {1523: [5555, 10196]}
# {1524: [18634, 22127]}
# {1525: [22973, 4182]}
# {1526: [17188, 18128]}
# {1527: [16127, 17052]}
# {1528: [11466, 23918]}
# {1529: [8465, 17472]}
# {1530: [2576, 15283]}
# {1531: [2325, 16591]}
# {1532: [23530, 21976]}
# {1533: [4147, 4073]}
# {1534: [23920, 6640]}
# {1535: [23889, 3798]}
# {1536: [1969, 22190]}
# {1537: [17969, 1807]}
# {1538: [19002, 20298]}
# {1539: [19578, 23106]}
# {1540: [10577, 9821]}
# {1541: [1403, 16643]}
# {1542: [745, 15017]}
# {1543: [4063, 15726]}
# {1544: [13212, 17136]}
# {1545: [2136, 2980]}
# {1546: [8387, 18056]}
# {1547: [13126, 16370]}
# {1548: [4709, 12847]}
# {1549: [13575, 19006]}
# {1550: [4628, 18728]}
# {1551: [16546, 315]}
# {1552: [7706, 2182]}
# {1553: [10155, 19329]}
# {1554: [10886, 11684]}
# {1555: [2429, 10144]}
# {1556: [15981, 5205]}
# {1557: [17385, 11833]}
# {1558: [3988, 5956]}
# {1559: [21330, 12951]}
# {1560: [6047, 3984]}
# {1561: [9363, 11084]}
# {1562: [20134, 1539]}
# {1563: [11709, 11468]}
# {1564: [17138, 12]}
# {1565: [20529, 14073]}
# {1566: [23411, 1290]}
# {1567: [21093, 6739]}
# {1568: [7205, 9852]}
# {1569: [16010, 9181]}
# {1570: [19951, 938]}
# {1571: [7828, 18722]}
# {1572: [16693, 14857]}
# {1573: [5822, 6628]}
# {1574: [2193, 257]}
# {1575: [15929, 21357]}
# {1576: [23560, 13319]}
# {1577: [6748, 13731]}
# {1578: [8532, 2251]}
# {1579: [17810, 4785]}
# {1580: [9163, 14010]}
# {1581: [9040, 12867]}
# {1582: [6163, 2498]}
# {1583: [22182, 6800]}
# {1584: [13357, 10127]}
# {1585: [2625, 17824]}
# {1586: [2197, 3657]}
# {1587: [747, 6169]}
# {1588: [20489, 8770]}
# {1589: [9417, 3713]}
# {1590: [5605, 20379]}
# {1591: [14578, 17700]}
# {1592: [7225, 16036]}
# {1593: [2682, 3511]}
# {1594: [5151, 23898]}
# {1595: [13466, 11610]}
# {1596: [22887, 14478]}
# {1597: [1189, 6161]}
# {1598: [5598, 18345]}
# {1599: [2744, 22924]}
# {1600: [14741, 4999]}
# {1601: [5266, 17754]}
# {1602: [10250, 8638]}
# {1603: [3802, 10022]}
# {1604: [11459, 17283]}
# {1605: [3775, 20118]}
# {1606: [17446, 1726]}
# {1607: [13245, 2163]}
# {1608: [20702, 4723]}
# {1609: [11936, 8280]}
# {1610: [17961, 23397]}
# {1611: [8596, 429]}
# {1612: [10279, 58]}
# {1613: [21165, 6362]}
# {1614: [6359, 6098]}
# {1615: [8164, 5637]}
# {1616: [13680, 20198]}
# {1617: [6303, 1068]}
# {1618: [23153, 20720]}
# {1619: [43, 20493]}
# {1620: [15847, 20704]}
# {1621: [5427, 23197]}
# {1622: [4901, 9255]}
# {1623: [580, 906]}
# {1624: [11627, 8654]}
# {1625: [6767, 21923]}
# {1626: [18790, 13548]}
# {1627: [11443, 22770]}
# {1628: [7761, 7921]}
# {1629: [20731, 1154]}
# {1630: [18173, 618]}
# {1631: [7410, 18702]}
# {1632: [2745, 22449]}
# {1633: [12585, 19155]}
# {1634: [5435, 7273]}
# {1635: [2672, 17254]}
# {1636: [21270, 30]}
# {1637: [17011, 6113]}
# {1638: [11569, 13643]}
# {1639: [10790, 614]}
# {1640: [10824, 19358]}
# {1641: [20578, 9522]}
# {1642: [519, 22006]}
# {1643: [21262, 22072]}
# {1644: [16172, 13352]}
# {1645: [19267, 206]}
# {1646: [1672, 22531]}
# {1647: [15061, 9710]}
# {1648: [19853, 18937]}
# {1649: [7757, 19770]}
# {1650: [21982, 22602]}
# {1651: [11902, 17967]}
# {1652: [22616, 22300]}
# {1653: [15710, 4005]}
# {1654: [4218, 14506]}
# {1655: [18331, 22863]}
# {1656: [3296, 15051]}
# {1657: [333, 12797]}
# {1658: [658, 1934]}
# {1659: [5895, 20364]}
# {1660: [16461, 12186]}
# {1661: [2236, 6318]}
# {1662: [1618, 13436]}
# {1663: [15985, 5690]}
# {1664: [12210, 22096]}
# {1665: [2610, 13733]}
# {1666: [22795, 6765]}
# {1667: [5067, 6010]}
# {1668: [8263, 14202]}
# {1669: [19230, 47]}
# {1670: [15270, 23296]}
# {1671: [795, 16828]}
# {1672: [2632, 8723]}
# {1673: [611, 22624]}
# {1674: [6342, 6989]}
# {1675: [896, 3827]}
# {1676: [21638, 1393]}
# {1677: [15279, 15622]}
# {1678: [19623, 2251]}
# {1679: [10507, 17098]}
# {1680: [5436, 11333]}
# {1681: [17259, 6147]}
# {1682: [17543, 15830]}
# {1683: [13006, 18180]}
# {1684: [18493, 21848]}
# {1685: [23612, 4146]}
# {1686: [16164, 18315]}
# {1687: [9775, 7247]}
# {1688: [5883, 15049]}
# {1689: [18155, 1446]}
# {1690: [6289, 8770]}
# {1691: [16384, 11968]}
# {1692: [12691, 12140]}
# {1693: [17638, 20098]}
# {1694: [18834, 6423]}
# {1695: [2155, 19660]}
# {1696: [13661, 11638]}
# {1697: [8163, 16668]}
# {1698: [15958, 7523]}
# {1699: [9572, 4821]}
# {1700: [7395, 18616]}
# {1701: [6426, 12928]}
# {1702: [18682, 1618]}
# {1703: [6578, 23735]}
# {1704: [4838, 18404]}
# {1705: [20726, 14276]}
# {1706: [41, 22753]}
# {1707: [15764, 1188]}
# {1708: [11635, 16557]}
# {1709: [7389, 16211]}
# {1710: [7866, 8015]}
# {1711: [21126, 21706]}
# {1712: [11848, 23469]}
# {1713: [5323, 6002]}
# {1714: [5234, 1438]}
# {1715: [18390, 20507]}
# {1716: [3527, 7237]}
# {1717: [2840, 7204]}
# {1718: [21560, 22710]}
# {1719: [8571, 10079]}
# {1720: [11287, 7209]}
# {1721: [7242, 12840]}
# {1722: [135, 10295]}
# {1723: [23847, 19024]}
# {1724: [3519, 9386]}
# {1725: [8141, 17439]}
# {1726: [5401, 9546]}
# {1727: [11882, 10106]}
# {1728: [20267, 21932]}
# {1729: [13079, 2150]}
# {1730: [5833, 20186]}
# {1731: [20732, 17684]}
# {1732: [14922, 19052]}
# {1733: [14489, 15510]}
# {1734: [5949, 7064]}
# {1735: [6734, 10478]}
# {1736: [19886, 17652]}
# {1737: [9698, 16005]}
# {1738: [23755, 3157]}
# {1739: [7428, 11061]}
# {1740: [15011, 6390]}
# {1741: [279, 4482]}
# {1742: [5928, 3057]}
# {1743: [13322, 5233]}
# {1744: [13877, 22610]}
# {1745: [21060, 23842]}
# {1746: [13235, 394]}
# {1747: [23749, 9133]}
# {1748: [7185, 23347]}
# {1749: [8698, 4731]}
# {1750: [22268, 383]}
# {1751: [21798, 8177]}
# {1752: [12775, 1853]}
# {1753: [5363, 5028]}
# {1754: [16685, 4565]}
# {1755: [7238, 22939]}
# {1756: [10213, 8984]}
# {1757: [4960, 1229]}
# {1758: [7558, 20256]}
# {1759: [21860, 20699]}
# {1760: [18972, 5304]}
# {1761: [7013, 4706]}
# {1762: [5894, 17106]}
# {1763: [6231, 11153]}
# {1764: [11872, 19220]}
# {1765: [8521, 14986]}
# {1766: [22153, 3388]}
# {1767: [17966, 9840]}
# {1768: [16530, 5941]}
# {1769: [2699, 11527]}
# {1770: [7209, 683]}
# {1771: [13108, 22728]}
# {1772: [22063, 1551]}
# {1773: [3253, 70]}
# {1774: [4837, 20489]}
# {1775: [14524, 15330]}
# {1776: [2088, 9562]}
# {1777: [4841, 23329]}
# {1778: [938, 506]}
# {1779: [3238, 21410]}
# {1780: [7973, 3840]}
# {1781: [22617, 7908]}
# {1782: [5887, 17019]}
# {1783: [20665, 16243]}
# {1784: [21456, 414]}
# {1785: [11101, 13443]}
# {1786: [16123, 22102]}
# {1787: [22831, 10863]}
# {1788: [10264, 11349]}
# {1789: [1481, 9365]}
# {1790: [22819, 16234]}
# {1791: [6749, 14819]}
# {1792: [18411, 2791]}
# {1793: [19934, 5193]}
# {1794: [9515, 20972]}
# {1795: [1953, 2552]}
# {1796: [6691, 15944]}
# {1797: [11990, 13396]}
# {1798: [170, 14770]}
# {1799: [23651, 4566]}
# {1800: [9251, 11124]}
# {1801: [10454, 9868]}
# {1802: [10052, 9769]}
# {1803: [19170, 2508]}
# {1804: [7164, 19216]}
# {1805: [3659, 17630]}
# {1806: [19161, 12960]}
# {1807: [7700, 18847]}
# {1808: [5804, 5210]}
# {1809: [21321, 23522]}
# {1810: [8466, 8705]}
# {1811: [21271, 20103]}
# {1812: [23614, 8996]}
# {1813: [11510, 22733]}
# {1814: [9632, 23483]}
# {1815: [977, 8427]}
# {1816: [5980, 5370]}
# {1817: [21249, 20559]}
# {1818: [14098, 3367]}
# {1819: [18998, 22935]}
# {1820: [16533, 15352]}
# {1821: [18447, 21936]}
# {1822: [20706, 977]}
# {1823: [18708, 3117]}
# {1824: [20656, 2740]}
# {1825: [7277, 1738]}
# {1826: [16794, 93]}
# {1827: [2425, 19265]}
# {1828: [3542, 6867]}
# {1829: [10116, 4095]}
# {1830: [20353, 6720]}
# {1831: [22395, 12708]}
# {1832: [9093, 13439]}
# {1833: [21589, 2589]}
# {1834: [19910, 7741]}
# {1835: [16950, 8001]}
# {1836: [12500, 9459]}
# {1837: [23225, 17521]}
# {1838: [23468, 6950]}
# {1839: [4365, 12455]}
# {1840: [16440, 14993]}
# {1841: [17337, 18559]}
# {1842: [1745, 14168]}
# {1843: [14764, 20688]}
# {1844: [18343, 5603]}
# {1845: [2958, 18931]}
# {1846: [20289, 13106]}
# {1847: [15060, 7108]}
# {1848: [13490, 23321]}
# {1849: [14927, 10290]}
# {1850: [19825, 21799]}
# {1851: [6999, 22788]}
# {1852: [13406, 711]}
# {1853: [16513, 23900]}
# {1854: [4685, 5002]}
# {1855: [13794, 10698]}
# {1856: [14845, 21987]}
# {1857: [5544, 22765]}
# {1858: [22399, 22419]}
# {1859: [13641, 6865]}
# {1860: [20613, 17610]}
