# %%
import numpy as np
import matplotlib.pyplot as plt
import copy

fl=open("result.txt","w")


def sum(a):
    b=0
    for i in a:
        b+=i
    return b

def cut(f):
    if(len(f)==0): return []
    i=0
    while(f[i]==0):
        i+=1
        if(i==len(f)): return []
    return f[i::]

def analit(a,st=0):
    b=len(a)-1+st
    s=""
    for i in a:
        if(i!=0):
            if(i!=1 or b==0):
                s+=str(i)
            if(b>0):s+="x**"+str(b)
            s+="+"
        b-=1
    if(len(s)==0):s="0+"
    return s[0:-1:]


def GCD(f,g,mod,show=1,write=1):
    #if(len(f)<len(g)):f,g=g,f
    if(show):print("Counting for mod "+str(mod))
    if(write):fl.write("Counting for mod "+str(mod))
    retarr=[]
    retarr.append([copy.deepcopy(f),[-0],1,0])
    if(show):print(str(retarr[-1]))
    if(write):fl.write(str(retarr[-1]))
    retarr.append([copy.deepcopy(g),[-0],0,1])
    if(show):print(str(retarr[-1]))
    if(write):fl.write(str(retarr[-1]))


    g=cut(g)
    while(len(g)>0):
        n = len(g)#min(len(f),len(g))
        s=""
        ka=[]
        while(len(f)>=len(g)):
            k=0
            iter=0
            
            if(show):
                print(analit(f))
            if(write):
                fl.write(analit(f))
                
            while(f[0]>0):
                k+=1
                f[0]=(f[0]-g[0]+mod)%mod
                iter+=1
                if(iter==mod+1):
                    retarr.append([copy.deepcopy(f),"nan","nan","nan"])
                    return retarr
            psa=[(g[i]*k)%mod for i in range (n)]
            for i in range(1,n):
                f[i]=(f[i]-g[i]*k+mod)%mod
            
            s+=str(k)
            ka.append(k)
            d=len(f)-n

            f=cut(f)        
            
            if(show):
                print("-"+analit(psa,d))
                print("="+analit(f))
            if(write):
                fl.write("-"+analit(psa,d))
                fl.write("="+analit(f))
                
            
            if(d>0):s+="x**"+str(d)
            s+="+"
        s=s[0:-1:]
        if(len(ka)==0):ka=[0]
        f=cut(f)
        #retarr.append([copy.deepcopy(f),s,"("+str(retarr[-2][2])+")-("+s+")*("+str(retarr[-1][2])+")","("+str(retarr[-2][3])+")-("+s+")*("+str(retarr[-1][3])+")"])
        retarr.append([copy.deepcopy(f),ka,"("+str(retarr[-2][2])+")-("+analit(ka)+")*("+str(retarr[-1][2])+")","("+str(retarr[-2][3])+")-("+analit(ka)+")*("+str(retarr[-1][3])+")"])
        if(show):print(str(retarr[-1]))
        if(write):fl.write(str(retarr[-1]))
    #     print(str(f))
    #     fl.write(str(f))
    #     print(g)
    #     fl.write(str(g))
    #     print(k)
    #     fl.write(str(k))
    #     print((g*k)%mod)
    #     fl.write(str((g*k)%mod))

        fl.flush()

        f,g=g,f
    
    if(show):print("End of counting")
    if(write):fl.write("End of counting")
    return retarr

def rev(f,mod,show,write):
    g=[mod for i in f]
    d=GCD(g,f,mod,show,write)
    flagf=1
    for i in d:
        if(flagf):
            flagf=0
            continue
        if(len(i[0])==1):
            b=copy.deepcopy(i)
            print (b)
            sc=1
            for j in range (1,mod+1):
                sc=j
                if(b[0][0]==1): 
                    return "("+str(b[-1])+"*"+str(sc)+")"
                    break
                b[0][0]=(b[0][0]+i[0][0])%mod
                print(b)
    return "nan"

if __name__=="__main__":

    f=np.array([4,4,4,2,2,3,4,1])
    g=np.array([3,4,2,1,2])
    mod=5#np.array([3,3,3,3,3])


    res=GCD(copy.deepcopy(f),copy.deepcopy(g),mod)
    print("("+str(res[-1][-2])+")*("+str(analit(res[0][0]))+") + ("+str(res[-1][-1])+")*("+str(analit(res[1][0]))+")")
    #Obratnii k f
    print("Obratnii k f = "+str(rev(f,mod,0,0)))
    #Obratnii k g
    print("Obratnii k g = "+str(rev(g,mod,0,0)))


fl.close()
# Out:
# Counting for mod 5
# [array([4, 4, 4, 2, 2, 3, 4, 1]), [0], 1, 0]
# [array([3, 4, 2, 1, 2]), [0], 0, 1]
# 4x**7+4x**6+4x**5+2x**4+2x**3+3x**2+4x**1+1
# -4x**7+2x**6+x**5+3x**4+x**3
# =2x**6+3x**5+4x**4+x**3+3x**2+4x**1+1
# 2x**6+3x**5+4x**4+x**3+3x**2+4x**1+1
# -2x**6+x**5+3x**4+4x**3+3x**2
# =2x**5+x**4+2x**3+4x**1+1
# 2x**5+x**4+2x**3+4x**1+1
# -2x**5+x**4+3x**3+4x**2+3x**1
# =4x**3+x**2+x**1+1
# [array([4, 1, 1, 1]), [3, 4, 4], '(1)-(3x**2+4x**1+4)*(0)', '(0)-(3x**2+4x**1+4)*(1)']
# 3x**4+4x**3+2x**2+x**1+2
# -3x**4+2x**3+2x**2+2x**1
# =2x**3+4x**1+2
# 2x**3+4x**1+2
# -2x**3+3x**2+3x**1+3
# =2x**2+x**1+4
# [array([2, 1, 4]), [2, 3], '(0)-(2x**1+3)*((1)-(3x**2+4x**1+4)*(0))', '(1)-(2x**1+3)*((0)-(3x**2+4x**1+4)*(1))']
# 4x**3+x**2+x**1+1
# -4x**3+2x**2+3x**1
# =4x**2+3x**1+1
# 4x**2+3x**1+1
# -4x**2+2x**1+3
# =x**1+3
# [array([1, 3]), [2, 2], '((1)-(3x**2+4x**1+4)*(0))-(2x**1+2)*((0)-(2x**1+3)*((1)-(3x**2+4x**1+4)*(0)))', '((0)-(3x**2+4x**1+4)*(1))-(2x**1+2)*((1)-(2x**1+3)*((0)-(3x**2+4x**1+4)*(1)))']
# 2x**2+x**1+4
# -2x**2+x**1
# =4
# [array([4]), [2], '((0)-(2x**1+3)*((1)-(3x**2+4x**1+4)*(0)))-(2)*(((1)-(3x**2+4x**1+4)*(0))-(2x**1+2)*((0)-(2x**1+3)*((1)-(3x**2+4x**1+4)*(0))))', '((1)-(2x**1+3)*((0)-(3x**2+4x**1+4)*(1)))-(2)*(((0)-(3x**2+4x**1+4)*(1))-(2x**1+2)*((1)-(2x**1+3)*((0)-(3x**2+4x**1+4)*(1))))']
# x**1+3
# -x**1
# =3
# 3
# -3
# =0
# [[], [4, 2], '(((1)-(3x**2+4x**1+4)*(0))-(2x**1+2)*((0)-(2x**1+3)*((1)-(3x**2+4x**1+4)*(0))))-(4x**1+2)*(((0)-(2x**1+3)*((1)-(3x**2+4x**1+4)*(0)))-(2)*(((1)-(3x**2+4x**1+4)*(0))-(2x**1+2)*((0)-(2x**1+3)*((1)-(3x**2+4x**1+4)*(0)))))', '(((0)-(3x**2+4x**1+4)*(1))-(2x**1+2)*((1)-(2x**1+3)*((0)-(3x**2+4x**1+4)*(1))))-(4x**1+2)*(((1)-(2x**1+3)*((0)-(3x**2+4x**1+4)*(1)))-(2)*(((0)-(3x**2+4x**1+4)*(1))-(2x**1+2)*((1)-(2x**1+3)*((0)-(3x**2+4x**1+4)*(1)))))']
# End of counting
# ((((1)-(3x**2+4x**1+4)*(0))-(2x**1+2)*((0)-(2x**1+3)*((1)-(3x**2+4x**1+4)*(0))))-(4x**1+2)*(((0)-(2x**1+3)*((1)-(3x**2+4x**1+4)*(0)))-(2)*(((1)-(3x**2+4x**1+4)*(0))-(2x**1+2)*((0)-(2x**1+3)*((1)-(3x**2+4x**1+4)*(0))))))*(4x**7+4x**6+4x**5+2x**4+2x**3+3x**2+4x**1+1) + ((((0)-(3x**2+4x**1+4)*(1))-(2x**1+2)*((1)-(2x**1+3)*((0)-(3x**2+4x**1+4)*(1))))-(4x**1+2)*(((1)-(2x**1+3)*((0)-(3x**2+4x**1+4)*(1)))-(2)*(((0)-(3x**2+4x**1+4)*(1))-(2x**1+2)*((1)-(2x**1+3)*((0)-(3x**2+4x**1+4)*(1))))))*(3x**4+4x**3+2x**2+x**1+2)
# Obratnii k f = nan
# Obratnii k g = nan
